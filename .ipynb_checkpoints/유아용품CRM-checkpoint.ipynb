# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import platform
# 운영체제별 한글 폰트 설정
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정
# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %%
member_data = pd.read_csv('Member_data02.csv')
product_data = pd.read_csv('Product_data.csv')
sales_data = pd.read_csv('Sales_data02.csv', low_memory=False)

# %%
member_data = member_data.dropna(axis = 0)
member_data
# Out:
#                  ID 성별 결혼유무 거주지역    연령 결제등록카드    유입경로 자녀여부
# 0      2.018123e+14  여   기혼   인천  37.0   국민은행   인스타그램  Yes
# 1      2.018123e+14  여   기혼   제주  33.0   국민은행    검색광고  Yes
# 2      2.018123e+14  여   기혼   부산  32.0   하나은행  네이버블로그  Yes
# 3      2.018123e+14  여   미혼   경남  34.0   기업은행    지인추천   No
# 4      2.018123e+14  여   기혼   서울  32.0   신한은행    직접검색  Yes
# ...             ... ..  ...  ...   ...    ...     ...  ...
# 81089  2.019123e+14  여   기혼   경기  31.0   국민은행    오픈마켓  Yes
# 81090  2.019123e+14  여   기혼   경남  37.0   롯데카드    오픈마켓  Yes
# 81091  2.019123e+14  여   기혼   충북  26.0   삼성카드    검색광고  Yes
# 81092  2.019123e+14  여   기혼   경기  32.0  새마을금고   인스타그램  Yes
# 81093  2.019123e+14  여   기혼   서울  35.0  새마을금고   인스타그램  Yes
#
# [81094 rows x 8 columns]

# %%
product_data.head()
# Out:
#   물품대분류                               상품명  물품판매량  제품단가
# 0    FC        (1+1) 좋은느낌 입는 오버나이트 대형 8개입     15     0
# 1    FC        (1+1) 좋은느낌 입는 오버나이트 중형 8개입     10     0
# 2    FC  (1+1) 화이트 입는 오버나이트 대형 L 8개입 (EA)     27     0
# 3    FC  (1+1) 화이트 입는 오버나이트 중형 M 8개입 (EA)     12     0
# 4    FC   (핫딜위크/1+1) 좋은느낌 입는 오버나이트 대형 8개입      4     0

# %%
sales_data.head()
# Out:
#               주문번호         구매일       배송시작일       배송완료일  구매시월령(수정)  \
# 0  201905052342970  2019-05-06  2019-05-07  2019-05-11        4.0
# 1  202002203424450  2020-02-20  2020-02-21  2020-02-23       14.0
# 2  201902282095385  2019-02-28  2019-03-01  2019-03-05        NaN
# 3  201905132367003  2019-05-13  2019-05-14  2019-05-16       66.0
# 4  201905092356247  2019-05-10  2019-05-11  2019-05-13        5.0
#
#               고객번호   구매금액   결제금액 물품대분류                               상품명
# 0  201812310749735  25800  16314  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)
# 1  201812310749735  51200  37769    팬티  NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)
# 2  201812310749770   5610   3800   FMC            크리넥스？키즈용？화장지？3겹？27m 8롤
# 3  201812310749771  59520  47922   기저귀    하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)
# 4  201812310749774  50640  39788   기저귀   하기스 에어솔솔 썸머기저귀 3단계 공용 144매(밴드형)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   주문번호       199999 non-null  object
#  1   구매일        199999 non-null  object
#  2   배송시작일      199999 non-null  object
#  3   배송완료일      199999 non-null  object
#  4   구매시월령(수정)  168142 non-null  float64
#  5   고객번호       199999 non-null  object
#  6   구매금액       199999 non-null  int64
#  7   결제금액       199999 non-null  int64
#  8   물품대분류      199999 non-null  object
#  9   상품명        199999 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 15.3+ MB

# %%
sales_data.isnull().sum()
# Out:
# 주문번호             0
# 구매일              0
# 배송시작일            0
# 배송완료일            0
# 구매시월령(수정)    31857
# 고객번호             0
# 구매금액             0
# 결제금액             0
# 물품대분류            0
# 상품명              0
# dtype: int64

# %%
product_data[product_data['제품단가'] == 0]
# Out:
#      물품대분류                                  상품명  물품판매량  제품단가
# 0       FC           (1+1) 좋은느낌 입는 오버나이트 대형 8개입     15     0
# 1       FC           (1+1) 좋은느낌 입는 오버나이트 중형 8개입     10     0
# 2       FC     (1+1) 화이트 입는 오버나이트 대형 L 8개입 (EA)     27     0
# 3       FC     (1+1) 화이트 입는 오버나이트 중형 M 8개입 (EA)     12     0
# 4       FC      (핫딜위크/1+1) 좋은느낌 입는 오버나이트 대형 8개입      4     0
# ...    ...                                  ...    ...   ...
# 2896    팬티   하기스 네이처메이드 밤부 4단계 여아 120매(밴드형) X 3      1     0
# 2898    팬티    하기스 네이처메이드 밤부 5단계 남아 102매(밴드형) X2      1     0
# 2900    팬티  하기스 네이처메이드 썸머팬티 5단계 공용 68매(팬티형) X 3      6     0
# 2901    팬티  하기스 네이처메이드 썸머팬티 6단계 공용 58매(팬티형) X 3      1     0
# 2906    팬티   하기스 네이처메이드 오가닉 3단계 남아 128매(밴드형) X2      1     0
#
# [90 rows x 4 columns]

# %%
sales_data['주문번호'].nunique()
# Out:
# 182426

# %%
sac = sales_data[sales_data['주문번호'].str.contains('-')]

# %%
sac['고객번호'].nunique()
# Out:
# 13185

# %%
buy_day = sales_data.sort_values(by = '구매일')

# %%
member_data.groupby('유입경로').agg(where = ('자녀여부', 'count'))
# Out:
#         where
# 유입경로
# 검색광고     8259
# 네이버블로그  22684
# 네이버카페    5725
# 매장쿠폰      456
# 오픈마켓     2022
# 이마트       218
# 인스타그램   31167
# 지인추천     8021
# 직접검색     1137
# 페이스북     1405

# %%
# sales_data['구매시월령(수정)'] =  sales_data['구매시월령(수정)'] // 12 +1 -> 나이로 바꾸고 싶을떄

# %%
sales_data['구매시월령(수정)'].describe()
# Out:
# count    168142.000000
# mean         14.845458
# std          38.521315
# min         -10.000000
# 25%           2.000000
# 50%           6.000000
# 75%          13.000000
# max        1439.000000
# Name: 구매시월령(수정), dtype: float64

# %%
sales_data['구매시월령(수정)'][0]
# Out:
# 4.0

# %%
sales_data.boxplot(column = ['구매시월령(수정)'])
plt.show()

# %%
sales_data[sales_data['고객번호'] == '201812310749770']
# Out:
#               주문번호         구매일       배송시작일       배송완료일  구매시월령(수정)  \
# 2  201902282095385  2019-02-28  2019-03-01  2019-03-05        NaN
#
#               고객번호  구매금액  결제금액 물품대분류                     상품명
# 2  201812310749770  5610  3800   FMC  크리넥스？키즈용？화장지？3겹？27m 8롤

# %%
sales_data['구매시월령(수정)'].describe()
# Out:
# count    168142.000000
# mean         14.845458
# std          38.521315
# min         -10.000000
# 25%           2.000000
# 50%           6.000000
# 75%          13.000000
# max        1439.000000
# Name: 구매시월령(수정), dtype: float64

# %%
sns.histplot(sales_data, x="구매시월령(수정)")
# Out:
# <AxesSubplot:xlabel='구매시월령(수정)', ylabel='Count'>

# %%
over_ = sales_data[sales_data['구매시월령(수정)'] >= 8]
over_
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 1                  202002203424450  2020-02-20  2020-02-21  2020-02-23
# 3                  201905132367003  2019-05-13  2019-05-14  2019-05-16
# 5                  201907282649358  2019-07-29  2019-07-30  2019-08-02
# 17                 201909272881275  2019-09-28  2019-09-29  2019-10-01
# 18                 202001163303774  2020-01-17  2020-01-18  2020-01-20
# ...                            ...         ...         ...         ...
# 199962  20200616152300-27824950140  2020-06-17  2020-06-18  2020-06-20
# 199967  20200628072347-19416984457  2020-06-28  2020-06-29  2020-07-01
# 199974  20200620124150-32007118641  2020-06-20  2020-06-21  2020-06-23
# 199975  20200620124150-32007118641  2020-06-20  2020-06-21  2020-06-23
# 199991  20200801133708-97479383598  2020-08-01  2020-08-02  2020-08-04
#
#         구매시월령(수정)                  고객번호    구매금액   결제금액 물품대분류  \
# 1            14.0       201812310749735   51200  37769    팬티
# 3            66.0       201812310749771   59520  47922   기저귀
# 5             8.0       201812310749774  101280  76744   기저귀
# 17            8.0       201812310749784   47360  29952    팬티
# 18           12.0       201812310749784   13500  13500    기타
# ...           ...                   ...     ...    ...   ...
# 199962       23.0  20200603223916327908   43900  27372    팬티
# 199967       14.0  20200614095002296695    6900   5730   체험팩
# 199974      175.0  20200620123220059942    3150   2480   FMC
# 199975      175.0  20200620123220059942       0      0   FMC
# 199991       90.0  20200721194641507158   25480  25480  더블하트
#
#                                                       상품명
# 1                        NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)
# 3                          하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)
# 5                [2019년형] 하기스 에어솔솔 썸머기저귀 3단계 공용 144매(밴드형)
# 17                          하기스 맥스드라이 팬티 3단계 여아 116매(팬티형)
# 18                                    [필리앤임프스] 바디슈트 4종 택1
# ...                                                   ...
# 199962  2020 하기스 매직팬티 컴포트 썸머 3단계 공용 116매(팬티형) + 보너스 12...
# 199967          NEW 하기스 맥스드라이 팬티 4단계 공용 20매(팬티형/체험팩) (EA)
# 199974        [2020년 3월 신제품] 크리넥스 안심 물티슈 휴대용 20매X3개입 (EA)
# 199975  (1+1) 크리넥스 버블버블 핸드워시 그린향 거품펌프형 250ml + 용기형리필 2...
# 199991   더블하트 SofTouch 모유실감 PPSU젖병 노꼭지트윈팩 240ml (그린) (EA)
#
# [70166 rows x 10 columns]

# %%
sales_data['물품대분류'].unique()
# Out:
# array(['더블하트', '팬티', 'FMC', '기저귀', '체험팩', 'FC', '기타', '물티슈', 'SKC', 'SrC'],
#       dtype=object)

# %%
product_data['물품대분류'].unique()
# Out:
# array(['FC', 'FMC', 'SKC', 'SrC', '기저귀', '기타', '더블하트', '물티슈', '체험팩', '팬티'],
#       dtype=object)

# %%
product_data[product_data['물품대분류'] == 'FMC']
# Out:
#     물품대분류                                                상품명  물품판매량   제품단가
# 255   FMC  (1+1) 크리넥스 버블버블 핸드워시 그린향 거품펌프형 250ml + 용기형리필 2...     30      0
# 256   FMC  (1+1) 크리넥스 버블버블 핸드워시 상큼향 거품펌프형 250ml + 용기형리필 2...     17      0
# 257   FMC                            (핫딜위크/1+1) 스카트 주방 위생 세트     12      0
# 258   FMC               (핫딜위크/1+1) 크리넥스 칼로리라이트 키친타월 55매 X 3롤      6      0
# 259   FMC              [1+1] 스카트 항균 프레쉬블루 빨아쓰는 행주타월 45매 X 4롤     30  24800
# ..    ...                                                ...    ...    ...
# 475   FMC                           크리넥스 황사마스크 뉴디자인플러스 대형 3P    209  11866
# 476   FMC                           크리넥스 황사마스크 뉴디자인플러스 소형 3P    309  16037
# 477   FMC                             크리넥스 황사용 마스크 플러스 대형10P    222  19871
# 478   FMC                                        크리넥스/스카트 세트     54  38100
# 479   FMC                             크리넥스？키즈용？화장지？3겹？27m 8롤    450   8864
#
# [225 rows x 4 columns]

# %%
# member_data[member_data['ID'].str.contains('2018')]
member_data[member_data['ID'] == 2018]
# Out:
# Empty DataFrame
# Columns: [ID, 성별, 결혼유무, 거주지역, 연령, 결제등록카드, 유입경로, 자녀여부]
# Index: []

# %%
member_data['ID'].astype('float').max()
# Out:
# 201912291058171.0

# %%
member_data
# Out:
#                  ID 성별 결혼유무 거주지역    연령 결제등록카드    유입경로 자녀여부
# 0      2.018123e+14  여   기혼   인천  37.0   국민은행   인스타그램  Yes
# 1      2.018123e+14  여   기혼   제주  33.0   국민은행    검색광고  Yes
# 2      2.018123e+14  여   기혼   부산  32.0   하나은행  네이버블로그  Yes
# 3      2.018123e+14  여   미혼   경남  34.0   기업은행    지인추천   No
# 4      2.018123e+14  여   기혼   서울  32.0   신한은행    직접검색  Yes
# ...             ... ..  ...  ...   ...    ...     ...  ...
# 81089  2.019123e+14  여   기혼   경기  31.0   국민은행    오픈마켓  Yes
# 81090  2.019123e+14  여   기혼   경남  37.0   롯데카드    오픈마켓  Yes
# 81091  2.019123e+14  여   기혼   충북  26.0   삼성카드    검색광고  Yes
# 81092  2.019123e+14  여   기혼   경기  32.0  새마을금고   인스타그램  Yes
# 81093  2.019123e+14  여   기혼   서울  35.0  새마을금고   인스타그램  Yes
#
# [81094 rows x 8 columns]

# %%
member_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81094 entries, 0 to 81093
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      81094 non-null  float64
#  1   성별      81094 non-null  object
#  2   결혼유무    81094 non-null  object
#  3   거주지역    81094 non-null  object
#  4   연령      81094 non-null  float64
#  5   결제등록카드  81094 non-null  object
#  6   유입경로    81094 non-null  object
#  7   자녀여부    81094 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 5.6+ MB

# %%
sales_data['고객번호'] = sales_data['고객번호'].astype('float')

# %%
df = pd.merge(sales_data, member_data, right_on='ID', left_on = '고객번호')
merge_outer = pd.merge(sales_data, member_data, right_on='ID', left_on = '고객번호', how = 'left')

# %%
merge_outer['ID'] = merge_outer['ID'].astype('str')

# %%
product_data['total'] = product_data['물품판매량'] * product_data['제품단가']

# %%
product_data['total'].max()
# Out:
# 194683790

# %%
product_data[product_data['total'] == 194683790]
# Out:
#     물품대분류                          상품명  물품판매량   제품단가      total
# 768   기저귀  하기스 네이처메이드 2단계 여아 156매(밴드형)   3010  64679  194683790

# %%
no_outer = merge_outer[merge_outer['자녀여부'] == 'No']
yes_outer = merge_outer[merge_outer['자녀여부'] == 'Yes']

# %%
no_outer[no_outer['구매시월령(수정)'] >= 90]
# Out:
#                    주문번호         구매일       배송시작일       배송완료일  구매시월령(수정)  \
# 1923    201901151902351  2019-01-15  2019-01-16  2019-01-19      117.0
# 1924    201901151902351  2019-01-15  2019-01-16  2019-01-19      117.0
# 2723    201902272089585  2019-02-28  2019-03-01  2019-03-05      314.0
# 2724    201903312221678  2019-04-01  2019-04-02  2019-04-04      316.0
# 2725    201910243005683  2019-10-25  2019-10-26  2019-10-28      322.0
# ...                 ...         ...         ...         ...        ...
# 197214  201912193204396  2019-12-20  2019-12-21  2019-12-24      159.0
# 197326  201912193206380  2019-12-20  2019-12-21  2019-12-23      108.0
# 197590  202001273336894  2020-01-27  2020-01-28  2020-01-30      184.0
# 197997  201912203220117  2019-12-21  2019-12-22  2019-12-24       92.0
# 197998  201912203220117  2019-12-21  2019-12-22  2019-12-24       92.0
#
#                 고객번호   구매금액   결제금액 물품대분류                             상품명  \
# 1923    2.019010e+14  19800  13751   SKC          그린핑거 마이키즈 로션 대용량 330ml
# 1924    2.019010e+14   2600   2574    FC          좋은느낌 순수 울트라 날개 중형 18개입
# 2723    2.019010e+14  12900   8157  더블하트   더블하트 SofTouch 모유실감 젖꼭지 S (2입)
# 2724    2.019010e+14   9500   7137  더블하트                 더블하트 다기능 빨대 브러쉬
# 2725    2.019010e+14  12900   9187  더블하트   더블하트 SofTouch 모유실감 젖꼭지 L (2입)
# ...              ...    ...    ...   ...                             ...
# 197214  2.019122e+14  52800  30674   기저귀       하기스 보송보송 3단계 공용 186매(밴드형)
# 197326  2.019122e+14   7700   5227   FMC  크리넥스 안심 프리미엄 3겹 키친타월 140매 X 4롤
# 197590  2.019122e+14  12900   8064   FMC         크리넥스 3겹 수프림 소프트 27m 12롤
# 197997  2.019122e+14  22500  12474   SKC          그린핑거 마이키즈 샴푸 대용량 500ml
# 197998  2.019122e+14  15000   9355   SKC            그린핑거 마이키즈 얼굴로션 160ml
#
#                        ID 성별 결혼유무 거주지역    연령  결제등록카드    유입경로 자녀여부
# 1923    201901030751620.0  남   미혼   전남  31.0    우리은행  네이버블로그   No
# 1924    201901030751620.0  남   미혼   전남  31.0    우리은행  네이버블로그   No
# 2723    201901040752621.0  여   기혼   충북  32.0    우리은행   인스타그램   No
# 2724    201901040752621.0  여   기혼   충북  32.0    우리은행   인스타그램   No
# 2725    201901040752621.0  여   기혼   충북  32.0    우리은행   인스타그램   No
# ...                   ... ..  ...  ...   ...     ...     ...  ...
# 197214  201912191052918.0  여   미혼   서울  32.0  미래에셋증권    오픈마켓   No
# 197326  201912191053196.0  여   기혼   서울  31.0    BC카드    지인추천   No
# 197590  201912191053644.0  여   미혼   충북  33.0    광주은행   인스타그램   No
# 197997  201912201054504.0  여   기혼   경남  27.0    BC카드    검색광고   No
# 197998  201912201054504.0  여   기혼   경남  27.0    BC카드    검색광고   No
#
# [702 rows x 18 columns]

# %%
yes_outer[yes_outer['구매시월령(수정)'] >= 90]
# Out:
#                               주문번호         구매일       배송시작일       배송완료일  \
# 318                202001093283175  2020-01-10  2020-01-11  2020-01-13
# 439                201901011864727  2019-01-01  2019-01-02  2019-01-04
# 447                201903312218708  2019-03-31  2019-04-01  2019-04-03
# 448                201908302782324  2019-08-30  2019-08-31  2019-09-02
# 457                201903312221229  2019-04-01  2019-04-02  2019-04-04
# ...                            ...         ...         ...         ...
# 198319             202002123396582  2020-02-12  2020-02-13  2020-02-15
# 198769             201912253234186  2019-12-25  2019-12-26  2019-12-28
# 199023             202001313356450  2020-01-31  2020-02-01  2020-02-05
# 199024  20200623165452-20315027851  2020-06-24  2020-06-25  2020-06-27
# 199025  20200721093340-17817379046  2020-07-21  2020-07-22  2020-07-26
#
#         구매시월령(수정)          고객번호   구매금액   결제금액 물품대분류  \
# 318         167.0  2.019010e+14   3000   3000   체험팩
# 439          98.0  2.019010e+14  23800  18848   물티슈
# 447         101.0  2.019010e+14  12000   8266   FMC
# 448         106.0  2.019010e+14  17600  15324   FMC
# 457         341.0  2.019010e+14   2000   1584   FMC
# ...           ...           ...    ...    ...   ...
# 198319      143.0  2.019122e+14  54480  37622   기저귀
# 198769      112.0  2.019123e+14  16500  10286   SKC
# 199023      156.0  2.019123e+14   6040   4851   체험팩
# 199024      161.0  2.019123e+14   5900   5841   체험팩
# 199025      162.0  2.019123e+14   5900   5841   체험팩
#
#                                                    상품명                 ID 성별  \
# 318                                            맘큐 허그박스  201901010750103.0  여
# 439                       릴리유 무민 리미티드 아기물티슈 캡형 80매X10팩  201901010750193.0  남
# 447     “스페인하숙에 나온 바로 그 행주” 스카트 항균 프레쉬블루 행주타올 45매 X 4롤  201901010750202.0  여
# 448                     크리넥스 NEW 디럭스 미니_카카오 230매 X 6개입  201901010750202.0  여
# 457                        크리넥스 여행용티슈 카카오프렌즈 70매 X 3개입  201901010750221.0  여
# ...                                                ...                ... ..
# 198319                  하기스 네이처메이드 밤부 2단계 여아 156매(밴드형)  201912221055286.0  여
# 198769                           그린핑거 힘센 보습 울트라크림 300g  201912251056311.0  여
# 199023                   하기스 맥스드라이 3단계 공용 20매(밴드형/체험팩)  201912261056947.0  여
# 199024      NEW 하기스 네이처메이드 팬티 3단계 남아 20매(팬티형/체험팩) (EA)  201912261056947.0  여
# 199025       NEW 하기스 맥스드라이 팬티 3단계 공용 20매(팬티형/체험팩) (EA)  201912261056947.0  여
#
#        결혼유무 거주지역    연령  결제등록카드    유입경로 자녀여부
# 318      기혼   경기  32.0    국민은행    검색광고  Yes
# 439      기혼   부산  33.0  농협회원조합   네이버카페  Yes
# 447      기혼   서울  31.0    신한은행    검색광고  Yes
# 448      기혼   서울  31.0    신한은행    검색광고  Yes
# 457      기혼   부산  35.0    국민은행   인스타그램  Yes
# ...     ...  ...   ...     ...     ...  ...
# 198319   기혼   경남  38.0  농협회원조합   인스타그램  Yes
# 198769   기혼   경기  34.0    신한은행    오픈마켓  Yes
# 199023   기혼   경북  34.0    국민은행  네이버블로그  Yes
# 199024   기혼   경북  34.0    국민은행  네이버블로그  Yes
# 199025   기혼   경북  34.0    국민은행  네이버블로그  Yes
#
# [3537 rows x 18 columns]

# %%
product = product_data[['물품대분류', '상품명', '제품단가']]

# %%
df = df.merge(product, on = ['물품대분류', '상품명'])

# %%
df['배송시작일']=pd.to_datetime(df['배송시작일'],format = '%Y-%m-%d')
df['구매일']=pd.to_datetime(df['구매일'],format = '%Y-%m-%d')
df['배송완료일']=pd.to_datetime(df['배송완료일'],format = '%Y-%m-%d')

# %%
# Yes : 1, No : 0
df['자녀여부'] = df['자녀여부'].replace('Yes', 1).replace('No', 0)

# %%
df['배송기간'] = df['배송완료일'] -df['배송시작일']
df['구매에서 배송완료까지'] = df['배송완료일']- df['구매일']
df['배송시작기간'] = df['배송시작일'] - df['구매일']

df.drop(['주문번호', 'ID'], axis = 1, inplace = True)

# %%
# 여성 : 1, 남성 : 0
# 기혼 : 1, 미혼 : 0
# 출산예정 : 0
df['성별'] = df['성별']. replace('여', 1).replace('남', 0)
df['결혼유무'] = df['결혼유무'].replace('기혼', 1).replace('미혼', 0)
df['고객번호'].astype('float64')
df['구매시월령(수정)'] = df['구매시월령(수정)'].fillna(0)
df[df['구매시월령(수정)'] < 0]
# Out:
#               구매일      배송시작일      배송완료일  구매시월령(수정)          고객번호    구매금액  \
# 80     2019-01-31 2019-02-01 2019-02-03       -1.0  2.019011e+14   12900
# 88     2019-12-21 2019-12-22 2019-12-24       -5.0  2.019011e+14   12900
# 130    2019-01-17 2019-01-18 2019-01-21       -1.0  2.019011e+14   12900
# 136    2019-01-22 2019-01-23 2019-01-25       -1.0  2.019011e+14   12900
# 158    2019-01-31 2019-02-01 2019-02-04       -3.0  2.019011e+14   12900
# ...           ...        ...        ...        ...           ...     ...
# 199486 2020-04-03 2020-04-04 2020-04-06       -1.0  2.019102e+14   59000
# 199503 2019-11-08 2019-11-09 2019-11-11       -3.0  2.019103e+14   29900
# 199512 2019-12-18 2019-12-19 2019-12-22       -3.0  2.019111e+14   14500
# 199529 2020-07-09 2020-07-10 2020-07-12       -2.0  2.019112e+14       0
# 199570 2020-04-12 2020-04-13 2020-04-16       -1.0  2.019123e+14  169200
#
#           결제금액 물품대분류                                         상품명  성별  결혼유무  \
# 80        7662  더블하트               더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1
# 88       10216  더블하트               더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1
# 130       9692  더블하트               더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1
# 136      10206  더블하트               더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1
# 158       7662  더블하트               더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1
# ...        ...   ...                                         ...  ..   ...
# 199486   59000    기타  [에불로보] 프랑스 국민 애착인형 액티비티 기린 + 딸랑이 인형증정 (택1)   1     0
# 199503   29900    기타            [도담도담오가닉] 아기띠워머 외출용 3종 기획 특선-브라운   1     1
# 199512   14500    기타                      [필리앤임프스] 신생아 속싸개 6종 택1   1     1
# 199529       0    팬티           하기스 네이처메이드 밤부 4단계 여아 120매(밴드형) X2   1     1
# 199570  116186   기저귀          NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X3   1     1
#
#        거주지역    연령  결제등록카드    유입경로  자녀여부    제품단가   배송기간 구매에서 배송완료까지 배송시작기간
# 80       충남  27.0    롯데카드  네이버블로그     1   20583 2 days      3 days 1 days
# 88       인천  33.0    삼성카드   인스타그램     1   20583 2 days      3 days 1 days
# 130      부산  30.0    현대카드    지인추천     1   20583 3 days      4 days 1 days
# 136      서울  32.0    삼성카드  네이버블로그     1   20583 2 days      3 days 1 days
# 158      부산  32.0    하나은행    지인추천     1   20583 3 days      4 days 1 days
# ...     ...   ...     ...     ...   ...     ...    ...         ...    ...
# 199486   충북  40.0  농협회원조합  네이버블로그     0   59000 2 days      3 days 1 days
# 199503   대전  33.0    국민은행    오픈마켓     1   29900 2 days      3 days 1 days
# 199512   서울  35.0  농협회원조합   인스타그램     1   14500 3 days      4 days 1 days
# 199529   서울  31.0  농협회원조합  네이버블로그     1       0 2 days      3 days 1 days
# 199570   강원  37.0    국민은행    직접검색     1  169200 3 days      4 days 1 days
#
# [14568 rows x 20 columns]

# %%
def minus_change(i):
    if i < 0:
        return 0
    else:
        return i

df['구매시월령(수정)'] = df['구매시월령(수정)'].apply(minus_change)

# %%
data = pd.read_csv('eda_data.csv')

# %%
data['고객번호'][199582]
# Out:
# 201912271057299.0

# %%
keyword = '유아|맘|모유|엄마|하기스|젖|아기|아가|베이비|콧물|그린핑거|핑크퐁|더블하트|누들앤부|출산|도담도담|드시모네|디어에코|라밀로우|룰라러브|리틀누|마마|마더|수유|맘마|매직캔|이유식|먼치킨|싸개|메릴린|몽슈레|신생아|유모차|턱받이|베베|보보앤부|본토이|브라이트|브리카|비박스|비츠|뽀드|뿌띠|쁘띠|치발기|실리만|페어리|야마토야|에르고|에불로보|오볼|원펀|율그란|카시트|필리앤|스페셜기프트SET|마밍|릴리유|굿나이트'

def change_kids(x):
    keyword = '유아|맘|모유|엄마|하기스|젖|아기|아가|베이비|콧물|그린핑거|핑크퐁|더블하트|누들앤부|출산|도담도담|드시모네|디어에코|라밀로우|룰라러브|리틀누|마마|마더|수유|맘마|매직캔|이유식|먼치킨|싸개|메릴린|몽슈레|신생아|유모차|턱받이|베베|보보앤부|본토이|브라이트|브리카|비박스|비츠|뽀드|뿌띠|쁘띠|치발기|실리만|페어리|야마토야|에르고|에불로보|오볼|원펀|율그란|카시트|필리앤|스페셜기프트SET|마밍|릴리유|굿나이트'
    if keyword in str(x):
        return "Yes"
    else:
        return "No"

# %%
df['상품명'].apply(change_kids)
# Out:
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 199578    No
# 199579    No
# 199580    No
# 199581    No
# 199582    No
# Name: 상품명, Length: 199583, dtype: object

# %%
before_year = df[df['구매일'] < '2019-08-08']
current_year = df[df['구매일'] > '2020-01-01']

# %%
current_year['구매일']
# Out:
# 14       2020-03-21
# 15       2020-04-01
# 54       2020-02-22
# 156      2020-03-22
# 157      2020-01-08
#             ...
# 199578   2020-02-26
# 199579   2020-03-05
# 199580   2020-03-05
# 199581   2020-03-06
# 199582   2020-04-08
# Name: 구매일, Length: 61876, dtype: datetime64[ns]

# %%
print(len(before_year))
print(len(current_year))
# Out:
# 66881
# 61876

# %%
df['배송기간'].describe()
# Out:
# count                       199583
# mean     2 days 08:53:25.355165520
# std      0 days 14:38:54.058152587
# min                2 days 00:00:00
# 25%                2 days 00:00:00
# 50%                2 days 00:00:00
# 75%                3 days 00:00:00
# max                4 days 00:00:00
# Name: 배송기간, dtype: object

# %%
return_customer = before_year.groupby('고객번호').agg(count = ('고객번호', 'count'))
return_customer = return_customer[return_customer['count'] >= 2]

# %%
total = data.groupby('고객번호').agg(count =( '고객번호', 'count'))
total_re_percent =len(total[total['count'] >= 2]) / len(total) * 100
total_re_percent
print(f'전체 재구매율은 {round(total_re_percent, 2)}% 입니다.')
# Out:
# 전체 재구매율은 44.7% 입니다.

# %%
x = ['재구매', '비구매']
y = [round(total_re_percent, 2), 100 - round(total_re_percent, 2)]



plt.title("전체 재구매비율")
plt.pie(y, labels=x, autopct='%1.1f%%')
plt.show()

# %%
return_customer
# Out:
#               count
# 고객번호
# 2.018123e+14      2
# 2.018123e+14      4
# 2.018123e+14      2
# 2.018123e+14      9
# 2.018123e+14      2
# ...             ...
# 2.019081e+14      3
# 2.019081e+14      2
# 2.019081e+14      2
# 2.019081e+14      2
# 2.019081e+14      2
#
# [13777 rows x 1 columns]

# %%
result_before = len(return_customer) / len(before_year) * 100

# %%
result_before
# Out:
# 20.599273336224037

# %%
current_year
# Out:
#               구매일      배송시작일      배송완료일  구매시월령(수정)          고객번호   구매금액  \
# 14     2020-03-21 2020-03-22 2020-03-24        5.0  2.019010e+14  12900
# 15     2020-04-01 2020-04-02 2020-04-04        5.0  2.019010e+14  12900
# 54     2020-02-22 2020-02-23 2020-02-25        5.0  2.019011e+14  12900
# 156    2020-03-22 2020-03-23 2020-03-25        6.0  2.019011e+14  12900
# 157    2020-01-08 2020-01-09 2020-01-11       14.0  2.019011e+14  12900
# ...           ...        ...        ...        ...           ...    ...
# 199578 2020-02-26 2020-02-27 2020-02-29        2.0  2.019123e+14  39600
# 199579 2020-03-05 2020-03-06 2020-03-08        2.0  2.019123e+14  39600
# 199580 2020-03-05 2020-03-06 2020-03-08        2.0  2.019123e+14  19800
# 199581 2020-03-06 2020-03-07 2020-03-09        2.0  2.019123e+14  19800
# 199582 2020-04-08 2020-04-09 2020-04-11        3.0  2.019123e+14   5000
#
#          결제금액 물품대분류                               상품명  성별  결혼유무 거주지역    연령  \
# 14       9702  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   대전  36.0
# 15       8167  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   대전  36.0
# 54       7840  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   경기  35.0
# 156     10216  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     0   서울  36.0
# 157      7662  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   경남  32.0
# ...       ...   ...                               ...  ..   ...  ...   ...
# 199578  39600    기타  [실리만] 실리콘 어린이 식탁매트(동물) WSB264-레몬   1     1   경기  31.0
# 199579  39600    기타  [실리만] 실리콘 어린이 식탁매트(동물) WSB264-하늘   1     1   경기  31.0
# 199580  19800    기타        [실리만] 실리콘 어린이 식판 WSB262 하늘   1     1   경기  31.0
# 199581  19800    기타        [실리만] 실리콘 어린이 식판 WSB262 하늘   1     1   경기  31.0
# 199582   5000    기타                [메릴린] 목보호쿠션-뉴욕스트리트   1     1   경기  31.0
#
#         결제등록카드    유입경로  자녀여부   제품단가   배송기간 구매에서 배송완료까지 배송시작기간
# 14        신한은행    검색광고     1  20583 2 days      3 days 1 days
# 15        신한은행    검색광고     1  20583 2 days      3 days 1 days
# 54        신한은행  네이버블로그     0  20583 2 days      3 days 1 days
# 156       롯데카드    지인추천     0  20583 2 days      3 days 1 days
# 157     농협회원조합   인스타그램     1  20583 2 days      3 days 1 days
# ...        ...     ...   ...    ...    ...         ...    ...
# 199578    우리은행   인스타그램     1  39600 2 days      3 days 1 days
# 199579    우리은행   인스타그램     1  39600 2 days      3 days 1 days
# 199580    우리은행   인스타그램     1  19800 2 days      3 days 1 days
# 199581    우리은행   인스타그램     1  19800 2 days      3 days 1 days
# 199582    우리은행   인스타그램     1   5000 2 days      3 days 1 days
#
# [61876 rows x 20 columns]

# %%
current_customer = current_year.groupby('고객번호').agg(count = ('고객번호', 'count'))
return_current = current_customer[current_customer['count'] >= 2]

# %%
result_current = len(return_current) / len(current_year) * 100
result_current
# Out:
# 21.431572823065487

# %%
x = ['재구매', '비구매']
y = [round(result_current, 2), 100 - round(result_current, 2)]

plt.title("2020년 재구매비율")
plt.pie(y, labels=x, autopct='%1.1f%%')
plt.show()

# %%
how_day = data.groupby(['거주지역', '배송기간', '물품대분류']).agg(count = ('고객번호', 'count')).reset_index()
how_day[how_day['물품대분류'] == '기저귀']
# Out:
#     거주지역    배송기간 물품대분류  count
# 3     강원  2 days   기저귀   2009
# 12    강원  3 days   기저귀    660
# 21    강원  4 days   기저귀    204
# 31    경기  2 days   기저귀   4976
# 40    경기  3 days   기저귀   1590
# 50    경기  4 days   기저귀    465
# 59    경남  2 days   기저귀    857
# 69    경남  3 days   기저귀    287
# 78    경남  4 days   기저귀     90
# 88    경북  2 days   기저귀   1033
# 97    경북  3 days   기저귀    327
# 106   경북  4 days   기저귀    109
# 116   광주  2 days   기저귀    622
# 125   광주  3 days   기저귀    193
# 134   광주  4 days   기저귀     57
# 143   대구  2 days   기저귀    703
# 152   대구  3 days   기저귀    240
# 161   대구  4 days   기저귀     54
# 170   대전  2 days   기저귀   1053
# 179   대전  3 days   기저귀    376
# 188   대전  4 days   기저귀     96
# 198   부산  2 days   기저귀   2211
# 207   부산  3 days   기저귀    725
# 216   부산  4 days   기저귀    176
# 225   서울  2 days   기저귀   4139
# 234   서울  3 days   기저귀   1389
# 243   서울  4 days   기저귀    399
# 253   인천  2 days   기저귀   1062
# 263   인천  3 days   기저귀    368
# 272   인천  4 days   기저귀    112
# 281   전남  2 days   기저귀    612
# 290   전남  3 days   기저귀    198
# 299   전남  4 days   기저귀     52
# 308   전북  2 days   기저귀    717
# 317   전북  3 days   기저귀    257
# 326   전북  4 days   기저귀     71
# 335   제주  2 days   기저귀    372
# 344   제주  3 days   기저귀    118
# 353   제주  4 days   기저귀     32
# 363   충남  2 days   기저귀   1842
# 372   충남  3 days   기저귀    637
# 381   충남  4 days   기저귀    162
# 390   충북  2 days   기저귀   2546
# 399   충북  3 days   기저귀    854
# 408   충북  4 days   기저귀    266

# %%
day_over = how_day[how_day['배송기간'] >= '3']
over = day_over[day_over['물품대분류'] == '기저귀']
over['total'] = over['count'].cumsum()
over
# Out:
# C:\Users\Song\AppData\Local\Temp\ipykernel_21992\1886052910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   over['total'] = over['count'].cumsum()
#     거주지역    배송기간 물품대분류  count  total
# 12    강원  3 days   기저귀    660    660
# 21    강원  4 days   기저귀    204    864
# 40    경기  3 days   기저귀   1590   2454
# 50    경기  4 days   기저귀    465   2919
# 69    경남  3 days   기저귀    287   3206
# 78    경남  4 days   기저귀     90   3296
# 97    경북  3 days   기저귀    327   3623
# 106   경북  4 days   기저귀    109   3732
# 125   광주  3 days   기저귀    193   3925
# 134   광주  4 days   기저귀     57   3982
# 152   대구  3 days   기저귀    240   4222
# 161   대구  4 days   기저귀     54   4276
# 179   대전  3 days   기저귀    376   4652
# 188   대전  4 days   기저귀     96   4748
# 207   부산  3 days   기저귀    725   5473
# 216   부산  4 days   기저귀    176   5649
# 234   서울  3 days   기저귀   1389   7038
# 243   서울  4 days   기저귀    399   7437
# 263   인천  3 days   기저귀    368   7805
# 272   인천  4 days   기저귀    112   7917
# 290   전남  3 days   기저귀    198   8115
# 299   전남  4 days   기저귀     52   8167
# 317   전북  3 days   기저귀    257   8424
# 326   전북  4 days   기저귀     71   8495
# 344   제주  3 days   기저귀    118   8613
# 353   제주  4 days   기저귀     32   8645
# 372   충남  3 days   기저귀    637   9282
# 381   충남  4 days   기저귀    162   9444
# 399   충북  3 days   기저귀    854  10298
# 408   충북  4 days   기저귀    266  10564

# %%
double_heart = data[data['상품명'].str.contains('더블하트')]
double_heart
# Out:
#         Unnamed: 0         구매일       배송시작일       배송완료일  구매시월령(수정)  \
# 0                0  2019-05-06  2019-05-07  2019-05-11        4.0
# 1                1  2019-01-01  2019-01-02  2019-01-04        1.0
# 2                2  2019-04-14  2019-04-15  2019-04-18        2.0
# 3                3  2019-05-21  2019-05-22  2019-05-25        0.0
# 4                4  2019-07-17  2019-07-18  2019-07-20        3.0
# ...            ...         ...         ...         ...        ...
# 199511      199511  2020-08-01  2020-08-02  2020-08-04        2.0
# 199525      199525  2020-05-17  2020-05-18  2020-05-21        3.0
# 199526      199526  2020-05-28  2020-05-29  2020-05-31        4.0
# 199527      199527  2020-07-03  2020-07-04  2020-07-06        4.0
# 199576      199576  2020-07-01  2020-07-02  2020-07-04        5.0
#
#                 고객번호   구매금액   결제금액 물품대분류                            상품명  ...  \
# 0       2.018123e+14  25800  16314  더블하트  더블하트 SofTouch 모유실감 젖꼭지 M (2입)  ...
# 1       2.018123e+14  25800  16314  더블하트  더블하트 SofTouch 모유실감 젖꼭지 M (2입)  ...
# 2       2.018123e+14  25800  17344  더블하트  더블하트 SofTouch 모유실감 젖꼭지 M (2입)  ...
# 3       2.018123e+14  12900   9692  더블하트  더블하트 SofTouch 모유실감 젖꼭지 M (2입)  ...
# 4       2.018123e+14  12900   9692  더블하트  더블하트 SofTouch 모유실감 젖꼭지 M (2입)  ...
# ...              ...    ...    ...   ...                            ...  ...
# 199511  2.019121e+14  17600  17420  더블하트         더블하트 베이비 크림 100ml (EA)  ...
# 199525  2.019112e+14  33120  31140  더블하트     더블하트 마그마그 스트로컵 올인원 세트 (EA)  ...
# 199526  2.019121e+14  33120  27210  더블하트     더블하트 마그마그 스트로컵 올인원 세트 (EA)  ...
# 199527  2.019122e+14  33120  31120  더블하트     더블하트 마그마그 스트로컵 올인원 세트 (EA)  ...
# 199576  2.019123e+14   6800   6730  더블하트       더블하트 노리개젖꼭지 2단계(핑크) (EA)  ...
#
#         결혼유무  거주지역    연령  결제등록카드    유입경로 자녀여부   제품단가    배송기간 구매에서 배송완료까지  \
# 0          1    인천  37.0    국민은행   인스타그램    1  20583  4 days      5 days
# 1          1    강원  33.0  농협회원조합   인스타그램    1  20583  2 days      3 days
# 2          1    대전  32.0   농협중앙회   네이버카페    1  20583  3 days      4 days
# 3          1    제주  32.0    롯데카드   네이버카페    1  20583  3 days      4 days
# 4          1    서울  31.0    국민은행   인스타그램    1  20583  2 days      3 days
# ...      ...   ...   ...     ...     ...  ...    ...     ...         ...
# 199511     1    전북  40.0    국민은행   네이버카페    1  17600  2 days      3 days
# 199525     1    충남  34.0    삼성카드  네이버블로그    1  33120  3 days      4 days
# 199526     1    서울  35.0    부산은행    지인추천    1  33120  2 days      3 days
# 199527     1    경기  36.0    롯데카드   인스타그램    1  33120  2 days      3 days
# 199576     1    부산  34.0    국민은행    지인추천    1   6800  2 days      3 days
#
#         배송시작기간
# 0       1 days
# 1       1 days
# 2       1 days
# 3       1 days
# 4       1 days
# ...        ...
# 199511  1 days
# 199525  1 days
# 199526  1 days
# 199527  1 days
# 199576  1 days
#
# [37183 rows x 21 columns]

# %%
data.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
delay_delivery_current = current_year[current_year['배송기간'] > '2 days']
delay_delivey_percent = len(delay_delivery_current) / len(current_year) * 100
delay_delivey_percent
# Out:
# 30.136078608830562

# %%
delay_delivery_before = before_year[before_year['배송기간'] > '2 days']
delay_delivery_percent_before = len(delay_delivery_before) / len(before_year) * 100
delay_delivery_percent_before
# Out:
# 29.960676425292682

# %%
data
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호   구매금액  \
# 0       2019-05-06  2019-05-07  2019-05-11        4.0  2.018123e+14  25800
# 1       2019-01-01  2019-01-02  2019-01-04        1.0  2.018123e+14  25800
# 2       2019-04-14  2019-04-15  2019-04-18        2.0  2.018123e+14  25800
# 3       2019-05-21  2019-05-22  2019-05-25        0.0  2.018123e+14  12900
# 4       2019-07-17  2019-07-18  2019-07-20        3.0  2.018123e+14  12900
# ...            ...         ...         ...        ...           ...    ...
# 199578  2020-02-26  2020-02-27  2020-02-29        2.0  2.019123e+14  39600
# 199579  2020-03-05  2020-03-06  2020-03-08        2.0  2.019123e+14  39600
# 199580  2020-03-05  2020-03-06  2020-03-08        2.0  2.019123e+14  19800
# 199581  2020-03-06  2020-03-07  2020-03-09        2.0  2.019123e+14  19800
# 199582  2020-04-08  2020-04-09  2020-04-11        3.0  2.019123e+14   5000
#
#          결제금액 물품대분류                               상품명  성별  결혼유무 거주지역    연령  \
# 0       16314  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   인천  37.0
# 1       16314  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   강원  33.0
# 2       17344  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   대전  32.0
# 3        9692  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   제주  32.0
# 4        9692  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   서울  31.0
# ...       ...   ...                               ...  ..   ...  ...   ...
# 199578  39600    기타  [실리만] 실리콘 어린이 식탁매트(동물) WSB264-레몬   1     1   경기  31.0
# 199579  39600    기타  [실리만] 실리콘 어린이 식탁매트(동물) WSB264-하늘   1     1   경기  31.0
# 199580  19800    기타        [실리만] 실리콘 어린이 식판 WSB262 하늘   1     1   경기  31.0
# 199581  19800    기타        [실리만] 실리콘 어린이 식판 WSB262 하늘   1     1   경기  31.0
# 199582   5000    기타                [메릴린] 목보호쿠션-뉴욕스트리트   1     1   경기  31.0
#
#         결제등록카드   유입경로  자녀여부   제품단가    배송기간 구매에서 배송완료까지  배송시작기간
# 0         국민은행  인스타그램     1  20583  4 days      5 days  1 days
# 1       농협회원조합  인스타그램     1  20583  2 days      3 days  1 days
# 2        농협중앙회  네이버카페     1  20583  3 days      4 days  1 days
# 3         롯데카드  네이버카페     1  20583  3 days      4 days  1 days
# 4         국민은행  인스타그램     1  20583  2 days      3 days  1 days
# ...        ...    ...   ...    ...     ...         ...     ...
# 199578    우리은행  인스타그램     1  39600  2 days      3 days  1 days
# 199579    우리은행  인스타그램     1  39600  2 days      3 days  1 days
# 199580    우리은행  인스타그램     1  19800  2 days      3 days  1 days
# 199581    우리은행  인스타그램     1  19800  2 days      3 days  1 days
# 199582    우리은행  인스타그램     1   5000  2 days      3 days  1 days
#
# [199583 rows x 20 columns]

# %%
data
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호   구매금액  \
# 0       2019-05-06  2019-05-07  2019-05-11        4.0  2.018123e+14  25800
# 1       2019-01-01  2019-01-02  2019-01-04        1.0  2.018123e+14  25800
# 2       2019-04-14  2019-04-15  2019-04-18        2.0  2.018123e+14  25800
# 3       2019-05-21  2019-05-22  2019-05-25        0.0  2.018123e+14  12900
# 4       2019-07-17  2019-07-18  2019-07-20        3.0  2.018123e+14  12900
# ...            ...         ...         ...        ...           ...    ...
# 199578  2020-02-26  2020-02-27  2020-02-29        2.0  2.019123e+14  39600
# 199579  2020-03-05  2020-03-06  2020-03-08        2.0  2.019123e+14  39600
# 199580  2020-03-05  2020-03-06  2020-03-08        2.0  2.019123e+14  19800
# 199581  2020-03-06  2020-03-07  2020-03-09        2.0  2.019123e+14  19800
# 199582  2020-04-08  2020-04-09  2020-04-11        3.0  2.019123e+14   5000
#
#          결제금액 물품대분류                               상품명  성별  결혼유무 거주지역    연령  \
# 0       16314  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   인천  37.0
# 1       16314  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   강원  33.0
# 2       17344  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   대전  32.0
# 3        9692  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   제주  32.0
# 4        9692  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1     1   서울  31.0
# ...       ...   ...                               ...  ..   ...  ...   ...
# 199578  39600    기타  [실리만] 실리콘 어린이 식탁매트(동물) WSB264-레몬   1     1   경기  31.0
# 199579  39600    기타  [실리만] 실리콘 어린이 식탁매트(동물) WSB264-하늘   1     1   경기  31.0
# 199580  19800    기타        [실리만] 실리콘 어린이 식판 WSB262 하늘   1     1   경기  31.0
# 199581  19800    기타        [실리만] 실리콘 어린이 식판 WSB262 하늘   1     1   경기  31.0
# 199582   5000    기타                [메릴린] 목보호쿠션-뉴욕스트리트   1     1   경기  31.0
#
#         결제등록카드   유입경로  자녀여부   제품단가    배송기간 구매에서 배송완료까지  배송시작기간
# 0         국민은행  인스타그램     1  20583  4 days      5 days  1 days
# 1       농협회원조합  인스타그램     1  20583  2 days      3 days  1 days
# 2        농협중앙회  네이버카페     1  20583  3 days      4 days  1 days
# 3         롯데카드  네이버카페     1  20583  3 days      4 days  1 days
# 4         국민은행  인스타그램     1  20583  2 days      3 days  1 days
# ...        ...    ...   ...    ...     ...         ...     ...
# 199578    우리은행  인스타그램     1  39600  2 days      3 days  1 days
# 199579    우리은행  인스타그램     1  39600  2 days      3 days  1 days
# 199580    우리은행  인스타그램     1  19800  2 days      3 days  1 days
# 199581    우리은행  인스타그램     1  19800  2 days      3 days  1 days
# 199582    우리은행  인스타그램     1   5000  2 days      3 days  1 days
#
# [199583 rows x 20 columns]

# %%
data['물품구매량'] =  data['구매금액']//data['제품단가']

# %%
data[data['물품구매량'] == 0]['상품명'].nunique()
# Out:
# 1598

# %%
count_zero = data[data['물품구매량'] == 0]
# count_zero.groupby('물품대분류').agg('결제금액', 'sum')
count_zero
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호   구매금액  \
# 3       2019-05-21  2019-05-22  2019-05-25        0.0  2.018123e+14  12900
# 4       2019-07-17  2019-07-18  2019-07-20        3.0  2.018123e+14  12900
# 5       2019-03-25  2019-03-26  2019-03-28        3.0  2.018123e+14  12900
# 8       2019-04-11  2019-04-12  2019-04-14        4.0  2.018123e+14  12900
# 9       2019-03-21  2019-03-22  2019-03-25        4.0  2.019010e+14  12900
# ...            ...         ...         ...        ...           ...    ...
# 199351  2020-05-28  2020-05-29  2020-05-31        6.0  2.019101e+14  16900
# 199370  2019-12-26  2019-12-27  2019-12-29        0.0  2.019092e+14  13500
# 199372  2020-02-27  2020-02-28  2020-03-03        7.0  2.019091e+14   8900
# 199408  2020-02-24  2020-02-25  2020-02-27        3.0  2.019093e+14   2100
# 199409  2020-02-24  2020-02-25  2020-02-27        0.0  2.019103e+14   2100
#
#          결제금액 물품대분류                                상품명  성별  ...  거주지역    연령  \
# 3        9692  더블하트      더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    제주  32.0
# 4        9692  더블하트      더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    서울  31.0
# 5        9692  더블하트      더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    경기  32.0
# 8        9692  더블하트      더블하트 SofTouch 모유실감 젖꼭지 M (2입)   0  ...    충남  31.0
# 9       10206  더블하트      더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    서울  30.0
# ...       ...   ...                                ...  ..  ...   ...   ...
# 199351  16900    기타  [맘마밀] 안심이유식 6개월 단호박과 소고기 100g 10팩   1  ...    서울  29.0
# 199370  13500    기타            [실리만] 실리콘 욕실 양치컵 WSS303   1  ...    경기  35.0
# 199372   8900    기타         [실리만] 실리콘 칫솔치발기 WSB241 연핑크   1  ...    대구  30.0
# 199408   2100    기타     [실리만] 실리콘 펭귄 핸드폰 거치대 WSA102 노랑   1  ...    전북  35.0
# 199409   2100    기타     [실리만] 실리콘 펭귄 핸드폰 거치대 WSA102 노랑   1  ...    서울  33.0
#
#         결제등록카드    유입경로 자녀여부   제품단가    배송기간 구매에서 배송완료까지  배송시작기간 물품구매량
# 3         롯데카드   네이버카페    1  20583  3 days      4 days  1 days   0.0
# 4         국민은행   인스타그램    1  20583  2 days      3 days  1 days   0.0
# 5         국민은행  네이버블로그    1  20583  2 days      3 days  1 days   0.0
# 8         현대카드   인스타그램    0  20583  2 days      3 days  1 days   0.0
# 9         신한카드  네이버블로그    1  20583  3 days      4 days  1 days   0.0
# ...        ...     ...  ...    ...     ...         ...     ...   ...
# 199351    국민은행   인스타그램    1  18233  2 days      3 days  1 days   0.0
# 199370    부산은행   인스타그램    0  20250  2 days      3 days  1 days   0.0
# 199372    신한은행    지인추천    1  11200  4 days      5 days  1 days   0.0
# 199408    국민카드   인스타그램    1   2800  2 days      3 days  1 days   0.0
# 199409    우리은행    지인추천    1   2800  2 days      3 days  1 days   0.0
#
# [123607 rows x 21 columns]

# %%
count_over1 = data[data['물품구매량'] > 0]
group_sum_over1 = count_over1.groupby('물품대분류').agg(sum_data = ('결제금액', 'sum'))
group_sum_over1
# Out:
#         sum_data
# 물품대분류
# FC      53256980
# FMC    111452227
# SKC     39960689
# SrC       167840
# 기저귀    483727222
# 기타      72821001
# 더블하트   248851681
# 물티슈     29162264
# 체험팩    174271612
# 팬티     419555908

# %%
group_sum_zero = count_zero.groupby('물품대분류').agg(sum_data_over1 = ('결제금액', 'sum'))
group_sum_zero
# Out:
#        sum_data_over1
# 물품대분류
# FC           39035203
# FMC         188318689
# SKC          76953049
# SrC             44640
# 기저귀        1088664467
# 기타           52771031
# 더블하트        392829447
# 물티슈         103426927
# 체험팩           5677185
# 팬티          752460522

# %%
total_sep = pd.concat([group_sum_over1, group_sum_zero], axis = 1)
total_sep['margin'] = total_sep['sum_data_over1'] - total_sep['sum_data']
total_sep = total_sep.sort_values(by = 'margin', ascending = False).reset_index()

sns.barplot(data=total_sep, x = '물품대분류', y = 'margin')
# Out:
# <AxesSubplot:xlabel='물품대분류', ylabel='margin'>

# %%
data[data['물품대분류'] == '기저귀']
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호    구매금액  \
# 3464    2019-05-13  2019-05-14  2019-05-16       66.0  2.018123e+14   59520
# 3465    2019-04-16  2019-04-17  2019-04-19        1.0  2.019010e+14   59520
# 3466    2019-12-15  2019-12-16  2019-12-19        8.0  2.019010e+14   59520
# 3467    2019-08-01  2019-08-02  2019-08-04        6.0  2.019010e+14  119040
# 3468    2019-05-17  2019-05-18  2019-05-20        4.0  2.019011e+14   59520
# ...            ...         ...         ...        ...           ...     ...
# 199545  2020-04-06  2020-04-07  2020-04-09        1.0  2.019121e+14  178560
# 199546  2020-04-06  2020-04-07  2020-04-10        3.0  2.019123e+14  178560
# 199557  2020-05-14  2020-05-15  2020-05-18        5.0  2.019122e+14       0
# 199569  2020-04-13  2020-04-14  2020-04-17        0.0  2.019122e+14  169200
# 199570  2020-04-12  2020-04-13  2020-04-16        0.0  2.019123e+14  169200
#
#           결제금액 물품대분류                                      상품명  성별  ...  거주지역  \
# 3464     47922   기저귀           하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)   1  ...    부산
# 3465     40689   기저귀           하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)   1  ...    전북
# 3466     35968   기저귀           하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)   1  ...    대구
# 3467     81464   기저귀           하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)   1  ...    대구
# 3468     43227   기저귀           하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)   1  ...    서울
# ...        ...   ...                                      ...  ..  ...   ...
# 199545  123151   기저귀       하기스 네이처메이드 밤부 3단계 여아 144매(밴드형) X 3   1  ...    경기
# 199546  121035   기저귀       하기스 네이처메이드 밤부 3단계 여아 144매(밴드형) X 3   1  ...    서울
# 199557       0   기저귀  하기스 NEW 네이처메이드 썸머 3단계 공용 120매(밴드형)  X 3   1  ...    경기
# 199569  111883   기저귀       NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X3   0  ...    서울
# 199570  116186   기저귀       NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X3   1  ...    강원
#
#           연령  결제등록카드    유입경로 자녀여부    제품단가    배송기간 구매에서 배송완료까지  배송시작기간 물품구매량
# 3464    32.0    하나은행  네이버블로그    1   65117  2 days      3 days  1 days   0.0
# 3465    29.0    기업은행    지인추천    1   65117  2 days      3 days  1 days   0.0
# 3466    35.0    신한카드  네이버블로그    0   65117  3 days      4 days  1 days   0.0
# 3467    34.0    하나은행   인스타그램    0   65117  2 days      3 days  1 days   1.0
# 3468    38.0  농협회원조합  네이버블로그    1   65117  2 days      3 days  1 days   0.0
# ...      ...     ...     ...  ...     ...     ...         ...     ...   ...
# 199545  32.0   새마을금고   인스타그램    1  178560  2 days      3 days  1 days   1.0
# 199546  28.0    롯데카드   인스타그램    1  178560  3 days      4 days  1 days   1.0
# 199557  34.0   신협중앙회    검색광고    1       0  3 days      4 days  1 days   NaN
# 199569  38.0    신한은행   네이버카페    1  169200  3 days      4 days  1 days   1.0
# 199570  37.0    국민은행    직접검색    1  169200  3 days      4 days  1 days   1.0
#
# [35318 rows x 21 columns]

# %%
data[data['물품대분류'] == '팬티']
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호    구매금액  \
# 2761    2020-02-20  2020-02-21  2020-02-23       14.0  2.018123e+14   51200
# 2762    2020-03-31  2020-04-01  2020-04-04       21.0  2.019010e+14   51200
# 2763    2020-03-08  2020-03-09  2020-03-13       14.0  2.019011e+14   51200
# 2764    2020-07-21  2020-07-22  2020-07-24       18.0  2.019011e+14   44300
# 2765    2020-02-06  2020-02-07  2020-02-09       10.0  2.019011e+14   51200
# ...            ...         ...         ...        ...           ...     ...
# 199500  2020-05-28  2020-05-29  2020-05-31        4.0  2.019122e+14   77900
# 199529  2020-07-09  2020-07-10  2020-07-12        0.0  2.019112e+14       0
# 199531  2019-12-06  2019-12-07  2019-12-09       24.0  2.019113e+14  142080
# 199532  2019-12-07  2019-12-08  2019-12-10       23.0  2.019121e+14  142080
# 199547  2019-12-09  2019-12-10  2019-12-13       13.0  2.019121e+14  142080
#
#          결제금액 물품대분류                                상품명  성별  ...  거주지역    연령  \
# 2761    37769    팬티   NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...    인천  37.0
# 2762    34637    팬티   NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...    서울  32.0
# 2763    33508    팬티   NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...    경북  33.0
# 2764    22570    팬티   NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...    경북  33.0
# 2765    34051    팬티   NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...    서울  34.0
# ...       ...   ...                                ...  ..  ...   ...   ...
# 199500  49208    팬티    하기스 네이처메이드 오가닉 3단계 남아 128매(밴드형)   1  ...    제주  33.0
# 199529      0    팬티  하기스 네이처메이드 밤부 4단계 여아 120매(밴드형) X2   1  ...    서울  31.0
# 199531  91773    팬티    하기스 맥스드라이 팬티 5단계 여아 80매(팬티형) X3   1  ...    전남  33.0
# 199532  92700    팬티    하기스 맥스드라이 팬티 5단계 여아 80매(팬티형) X3   1  ...    서울  33.0
# 199547  91773    팬티    하기스 맥스드라이 팬티 6단계 남아 68매(팬티형) X3   1  ...    강원  34.0
#
#         결제등록카드    유입경로 자녀여부    제품단가    배송기간 구매에서 배송완료까지  배송시작기간 물품구매량
# 2761      국민은행   인스타그램    1   53648  2 days      3 days  1 days   0.0
# 2762      롯데카드   인스타그램    1   53648  3 days      4 days  1 days   0.0
# 2763      신한은행   인스타그램    1   53648  4 days      5 days  1 days   0.0
# 2764      신한은행   인스타그램    1   53648  2 days      3 days  1 days   0.0
# 2765      기업은행    검색광고    1   53648  2 days      3 days  1 days   0.0
# ...        ...     ...  ...     ...     ...         ...     ...   ...
# 199500    우리은행   인스타그램    1   77900  2 days      3 days  1 days   1.0
# 199529  농협회원조합  네이버블로그    1       0  2 days      3 days  1 days   NaN
# 199531  농협회원조합   인스타그램    1  142080  2 days      3 days  1 days   1.0
# 199532    롯데카드   인스타그램    1  142080  2 days      3 days  1 days   1.0
# 199547  SC제일은행    지인추천    1  142080  3 days      4 days  1 days   1.0
#
# [27581 rows x 21 columns]

# %%
data.groupby(['고객번호']).agg(count = ('고객번호', 'count'))
# Out:
#               count
# 고객번호
# 2.018123e+14      2
# 2.018123e+14      1
# 2.018123e+14      1
# 2.018123e+14      2
# 2.018123e+14      1
# ...             ...
# 2.019123e+14      1
# 2.019123e+14      2
# 2.019123e+14      4
# 2.019123e+14      1
# 2.019123e+14      1
#
# [81094 rows x 1 columns]

# %%
produt_total = product_data.groupby('물품대분류').agg(product_storage = ('물품판매량', 'sum'))

# %%
def zero_change(x):
    if x == 0:
        return 1
    else:
        return x

data['물품구매량'] = data['물품구매량'].apply(zero_change)

# %%
customer_total = data.groupby('물품대분류').agg(customer_needs = ('물품구매량', 'sum'))

# %%
total_sells = pd.concat([produt_total, customer_total], axis = 1)

# %%
total_sells= total_sells.reset_index()
total_sells['shortage'] = total_sells['product_storage'] - total_sells['customer_needs']

# %%
product_detail = product_data.groupby('상품명').agg(check_produce_storage = ('물품판매량', 'sum'))
customer_detail = data.groupby('상품명').agg(check_customer_storage = ('물품구매량', 'sum'))
total_detail_data = pd.concat([product_detail, customer_detail],axis = 1)
customer_detail
# Out:
#                                                     check_customer_storage
# 상품명
# (1+1) 좋은느낌 입는 오버나이트 대형 8개입                                             0.0
# (1+1) 좋은느낌 입는 오버나이트 중형 8개입                                             0.0
# (1+1) 크리넥스 버블버블 핸드워시 그린향 거품펌프형 250ml + 용기형리필 25...                     0.0
# (1+1) 크리넥스 버블버블 핸드워시 상큼향 거품펌프형 250ml + 용기형리필 25...                     0.0
# (1+1) 화이트 입는 오버나이트 대형 L 8개입 (EA)                                       0.0
# ...                                                                    ...
# 화이트 탐폰 오가닉 레귤러 14개입                                                    7.0
# 화이트 탐폰 오가닉 슈퍼 14개입                                                     6.0
# 화이트 한듯안한듯 팬티라이너 롱 36개입                                                32.0
# 화이트 한듯안한듯 팬티라이너 롱 36개입 (EA)                                           12.0
# 화이트 한듯안한듯 팬티라이너 롱 36개입 X3                                              3.0
#
# [2975 rows x 1 columns]

# %%
total_detail_data['shortage'] = total_detail_data['check_produce_storage'] - total_detail_data['check_customer_storage']
total_detail_data[total_detail_data['shortage'] < 0]
# Out:
#                                                    check_produce_storage  \
# 상품명
# 2020 하기스 매직 컴포트 2단계 공용 246매(밴드형)                                     493
# 2020 하기스 매직 컴포트 4단계 공용 150매(밴드형)                                     393
# 2020 하기스 매직 컴포트 5단계 공용 126매(밴드형)                                     121
# 2020 하기스 매직팬티 컴포트 3단계 남아 160매(팬티형)                                   233
# 2020 하기스 매직팬티 컴포트 3단계 남아 160매(팬티형) + 보너스 16매 추가증정                     96
# ...                                                                  ...
# 화이트 탐폰 레귤러 16개입                                                       50
# 화이트 탐폰 슈퍼 16개입                                                        53
# 화이트 탐폰 오가닉 레귤러 14개입                                                    6
# 화이트 한듯안한듯 팬티라이너 롱 36개입                                                28
# 화이트 한듯안한듯 팬티라이너 롱 36개입 (EA)                                           11
#
#                                                    check_customer_storage  \
# 상품명
# 2020 하기스 매직 컴포트 2단계 공용 246매(밴드형)                                    499.0
# 2020 하기스 매직 컴포트 4단계 공용 150매(밴드형)                                    396.0
# 2020 하기스 매직 컴포트 5단계 공용 126매(밴드형)                                    122.0
# 2020 하기스 매직팬티 컴포트 3단계 남아 160매(팬티형)                                  234.0
# 2020 하기스 매직팬티 컴포트 3단계 남아 160매(팬티형) + 보너스 16매 추가증정                    98.0
# ...                                                                   ...
# 화이트 탐폰 레귤러 16개입                                                      52.0
# 화이트 탐폰 슈퍼 16개입                                                       56.0
# 화이트 탐폰 오가닉 레귤러 14개입                                                   7.0
# 화이트 한듯안한듯 팬티라이너 롱 36개입                                               32.0
# 화이트 한듯안한듯 팬티라이너 롱 36개입 (EA)                                          12.0
#
#                                                    shortage
# 상품명
# 2020 하기스 매직 컴포트 2단계 공용 246매(밴드형)                       -6.0
# 2020 하기스 매직 컴포트 4단계 공용 150매(밴드형)                       -3.0
# 2020 하기스 매직 컴포트 5단계 공용 126매(밴드형)                       -1.0
# 2020 하기스 매직팬티 컴포트 3단계 남아 160매(팬티형)                     -1.0
# 2020 하기스 매직팬티 컴포트 3단계 남아 160매(팬티형) + 보너스 16매 추가증정      -2.0
# ...                                                     ...
# 화이트 탐폰 레귤러 16개입                                        -2.0
# 화이트 탐폰 슈퍼 16개입                                         -3.0
# 화이트 탐폰 오가닉 레귤러 14개입                                    -1.0
# 화이트 한듯안한듯 팬티라이너 롱 36개입                                 -4.0
# 화이트 한듯안한듯 팬티라이너 롱 36개입 (EA)                            -1.0
#
# [714 rows x 3 columns]

# %%
data
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호   구매금액  \
# 0       2019-05-06  2019-05-07  2019-05-11        4.0  2.018123e+14  25800
# 1       2019-01-01  2019-01-02  2019-01-04        1.0  2.018123e+14  25800
# 2       2019-04-14  2019-04-15  2019-04-18        2.0  2.018123e+14  25800
# 3       2019-05-21  2019-05-22  2019-05-25        0.0  2.018123e+14  12900
# 4       2019-07-17  2019-07-18  2019-07-20        3.0  2.018123e+14  12900
# ...            ...         ...         ...        ...           ...    ...
# 199578  2020-02-26  2020-02-27  2020-02-29        2.0  2.019123e+14  39600
# 199579  2020-03-05  2020-03-06  2020-03-08        2.0  2.019123e+14  39600
# 199580  2020-03-05  2020-03-06  2020-03-08        2.0  2.019123e+14  19800
# 199581  2020-03-06  2020-03-07  2020-03-09        2.0  2.019123e+14  19800
# 199582  2020-04-08  2020-04-09  2020-04-11        3.0  2.019123e+14   5000
#
#          결제금액 물품대분류                               상품명  성별  ...  거주지역    연령  \
# 0       16314  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    인천  37.0
# 1       16314  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    강원  33.0
# 2       17344  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    대전  32.0
# 3        9692  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    제주  32.0
# 4        9692  더블하트     더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    서울  31.0
# ...       ...   ...                               ...  ..  ...   ...   ...
# 199578  39600    기타  [실리만] 실리콘 어린이 식탁매트(동물) WSB264-레몬   1  ...    경기  31.0
# 199579  39600    기타  [실리만] 실리콘 어린이 식탁매트(동물) WSB264-하늘   1  ...    경기  31.0
# 199580  19800    기타        [실리만] 실리콘 어린이 식판 WSB262 하늘   1  ...    경기  31.0
# 199581  19800    기타        [실리만] 실리콘 어린이 식판 WSB262 하늘   1  ...    경기  31.0
# 199582   5000    기타                [메릴린] 목보호쿠션-뉴욕스트리트   1  ...    경기  31.0
#
#         결제등록카드   유입경로 자녀여부   제품단가    배송기간 구매에서 배송완료까지  배송시작기간 물품구매량
# 0         국민은행  인스타그램    1  20583  4 days      5 days  1 days   1.0
# 1       농협회원조합  인스타그램    1  20583  2 days      3 days  1 days   1.0
# 2        농협중앙회  네이버카페    1  20583  3 days      4 days  1 days   1.0
# 3         롯데카드  네이버카페    1  20583  3 days      4 days  1 days   1.0
# 4         국민은행  인스타그램    1  20583  2 days      3 days  1 days   1.0
# ...        ...    ...  ...    ...     ...         ...     ...   ...
# 199578    우리은행  인스타그램    1  39600  2 days      3 days  1 days   1.0
# 199579    우리은행  인스타그램    1  39600  2 days      3 days  1 days   1.0
# 199580    우리은행  인스타그램    1  19800  2 days      3 days  1 days   1.0
# 199581    우리은행  인스타그램    1  19800  2 days      3 days  1 days   1.0
# 199582    우리은행  인스타그램    1   5000  2 days      3 days  1 days   1.0
#
# [199583 rows x 21 columns]

# %%
x = [2019, 2020]
y = [len(before_year), len(current_year)]
sns.barplot(x= x, y = y)
# Out:
# <AxesSubplot:>

# %%
print(len(before_year), len(current_year))
# Out:
# 66881 61876

# %%
data[data['물품대분류'] == '기저귀']['상품명'].nunique()
# Out:
# 224

# %%
data[data['물품대분류'] == '팬티']
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호    구매금액  \
# 2761    2020-02-20  2020-02-21  2020-02-23       14.0  2.018123e+14   51200
# 2762    2020-03-31  2020-04-01  2020-04-04       21.0  2.019010e+14   51200
# 2763    2020-03-08  2020-03-09  2020-03-13       14.0  2.019011e+14   51200
# 2764    2020-07-21  2020-07-22  2020-07-24       18.0  2.019011e+14   44300
# 2765    2020-02-06  2020-02-07  2020-02-09       10.0  2.019011e+14   51200
# ...            ...         ...         ...        ...           ...     ...
# 199500  2020-05-28  2020-05-29  2020-05-31        4.0  2.019122e+14   77900
# 199529  2020-07-09  2020-07-10  2020-07-12        0.0  2.019112e+14       0
# 199531  2019-12-06  2019-12-07  2019-12-09       24.0  2.019113e+14  142080
# 199532  2019-12-07  2019-12-08  2019-12-10       23.0  2.019121e+14  142080
# 199547  2019-12-09  2019-12-10  2019-12-13       13.0  2.019121e+14  142080
#
#          결제금액 물품대분류                                상품명  성별  ...  거주지역    연령  \
# 2761    37769    팬티   NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...    인천  37.0
# 2762    34637    팬티   NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...    서울  32.0
# 2763    33508    팬티   NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...    경북  33.0
# 2764    22570    팬티   NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...    경북  33.0
# 2765    34051    팬티   NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...    서울  34.0
# ...       ...   ...                                ...  ..  ...   ...   ...
# 199500  49208    팬티    하기스 네이처메이드 오가닉 3단계 남아 128매(밴드형)   1  ...    제주  33.0
# 199529      0    팬티  하기스 네이처메이드 밤부 4단계 여아 120매(밴드형) X2   1  ...    서울  31.0
# 199531  91773    팬티    하기스 맥스드라이 팬티 5단계 여아 80매(팬티형) X3   1  ...    전남  33.0
# 199532  92700    팬티    하기스 맥스드라이 팬티 5단계 여아 80매(팬티형) X3   1  ...    서울  33.0
# 199547  91773    팬티    하기스 맥스드라이 팬티 6단계 남아 68매(팬티형) X3   1  ...    강원  34.0
#
#         결제등록카드    유입경로 자녀여부    제품단가    배송기간 구매에서 배송완료까지  배송시작기간 물품구매량
# 2761      국민은행   인스타그램    1   53648  2 days      3 days  1 days   1.0
# 2762      롯데카드   인스타그램    1   53648  3 days      4 days  1 days   1.0
# 2763      신한은행   인스타그램    1   53648  4 days      5 days  1 days   1.0
# 2764      신한은행   인스타그램    1   53648  2 days      3 days  1 days   1.0
# 2765      기업은행    검색광고    1   53648  2 days      3 days  1 days   1.0
# ...        ...     ...  ...     ...     ...         ...     ...   ...
# 199500    우리은행   인스타그램    1   77900  2 days      3 days  1 days   1.0
# 199529  농협회원조합  네이버블로그    1       0  2 days      3 days  1 days   NaN
# 199531  농협회원조합   인스타그램    1  142080  2 days      3 days  1 days   1.0
# 199532    롯데카드   인스타그램    1  142080  2 days      3 days  1 days   1.0
# 199547  SC제일은행    지인추천    1  142080  3 days      4 days  1 days   1.0
#
# [27581 rows x 21 columns]

# %%
data[data['물품대분류'] == '기저귀']
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호    구매금액  \
# 3464    2019-05-13  2019-05-14  2019-05-16       66.0  2.018123e+14   59520
# 3465    2019-04-16  2019-04-17  2019-04-19        1.0  2.019010e+14   59520
# 3466    2019-12-15  2019-12-16  2019-12-19        8.0  2.019010e+14   59520
# 3467    2019-08-01  2019-08-02  2019-08-04        6.0  2.019010e+14  119040
# 3468    2019-05-17  2019-05-18  2019-05-20        4.0  2.019011e+14   59520
# ...            ...         ...         ...        ...           ...     ...
# 199545  2020-04-06  2020-04-07  2020-04-09        1.0  2.019121e+14  178560
# 199546  2020-04-06  2020-04-07  2020-04-10        3.0  2.019123e+14  178560
# 199557  2020-05-14  2020-05-15  2020-05-18        5.0  2.019122e+14       0
# 199569  2020-04-13  2020-04-14  2020-04-17        0.0  2.019122e+14  169200
# 199570  2020-04-12  2020-04-13  2020-04-16        0.0  2.019123e+14  169200
#
#           결제금액 물품대분류                                      상품명  성별  ...  거주지역  \
# 3464     47922   기저귀           하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)   1  ...    부산
# 3465     40689   기저귀           하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)   1  ...    전북
# 3466     35968   기저귀           하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)   1  ...    대구
# 3467     81464   기저귀           하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)   1  ...    대구
# 3468     43227   기저귀           하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)   1  ...    서울
# ...        ...   ...                                      ...  ..  ...   ...
# 199545  123151   기저귀       하기스 네이처메이드 밤부 3단계 여아 144매(밴드형) X 3   1  ...    경기
# 199546  121035   기저귀       하기스 네이처메이드 밤부 3단계 여아 144매(밴드형) X 3   1  ...    서울
# 199557       0   기저귀  하기스 NEW 네이처메이드 썸머 3단계 공용 120매(밴드형)  X 3   1  ...    경기
# 199569  111883   기저귀       NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X3   0  ...    서울
# 199570  116186   기저귀       NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X3   1  ...    강원
#
#           연령  결제등록카드    유입경로 자녀여부    제품단가    배송기간 구매에서 배송완료까지  배송시작기간 물품구매량
# 3464    32.0    하나은행  네이버블로그    1   65117  2 days      3 days  1 days   1.0
# 3465    29.0    기업은행    지인추천    1   65117  2 days      3 days  1 days   1.0
# 3466    35.0    신한카드  네이버블로그    0   65117  3 days      4 days  1 days   1.0
# 3467    34.0    하나은행   인스타그램    0   65117  2 days      3 days  1 days   1.0
# 3468    38.0  농협회원조합  네이버블로그    1   65117  2 days      3 days  1 days   1.0
# ...      ...     ...     ...  ...     ...     ...         ...     ...   ...
# 199545  32.0   새마을금고   인스타그램    1  178560  2 days      3 days  1 days   1.0
# 199546  28.0    롯데카드   인스타그램    1  178560  3 days      4 days  1 days   1.0
# 199557  34.0   신협중앙회    검색광고    1       0  3 days      4 days  1 days   NaN
# 199569  38.0    신한은행   네이버카페    1  169200  3 days      4 days  1 days   1.0
# 199570  37.0    국민은행    직접검색    1  169200  3 days      4 days  1 days   1.0
#
# [35318 rows x 21 columns]

# %%
data['물품구매량'] = data['물품구매량'].fillna(1)

# %%
def quater(x):
    if x <= '2019-03':
        return '2019 1Q'
    elif x <= '2019-06':
        return '2019 2Q'
    elif x <= '2019-09':
        return '2019 3Q'
    elif x <= '2019-12':
        return '2019 4Q'
    elif x <= '2020-03':
        return '2020 1Q'
    elif x <= '2020-06':
        return '2020 2Q'
    else:
        return '2020 3Q'

data[data['구매일'] <= '2019-03']
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호   구매금액  \
# 1       2019-01-01  2019-01-02  2019-01-04        1.0  2.018123e+14  25800
# 7       2019-01-01  2019-01-02  2019-01-04        4.0  2.018123e+14  25800
# 12      2019-01-05  2019-01-06  2019-01-08        0.0  2.019010e+14  25800
# 13      2019-02-28  2019-03-01  2019-03-03        3.0  2.019010e+14  12900
# 24      2019-02-22  2019-02-23  2019-02-26        2.0  2.019010e+14  25800
# ...            ...         ...         ...        ...           ...    ...
# 195750  2019-02-14  2019-02-15  2019-02-18        0.0  2.019021e+14  18500
# 195752  2019-02-24  2019-02-25  2019-02-27      107.0  2.019022e+14  18500
# 196188  2019-02-13  2019-02-14  2019-02-17      203.0  2.019021e+14  38900
# 196509  2019-02-22  2019-02-23  2019-02-25       80.0  2.019022e+14   9900
# 196854  2019-02-25  2019-02-26  2019-02-28        0.0  2.019022e+14  11900
#
#          결제금액 물품대분류                                 상품명  성별  ...  거주지역    연령  \
# 1       16314  더블하트       더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    강원  33.0
# 7       16314  더블하트       더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    경기  36.0
# 12      16314  더블하트       더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    서울  35.0
# 13       8157  더블하트       더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    서울  34.0
# 24      18234  더블하트       더블하트 SofTouch 모유실감 젖꼭지 M (2입)   1  ...    경기  34.0
# ...       ...   ...                                 ...  ..  ...   ...   ...
# 195750  14652    기타     티엔 BT21 AC컨트롤 데일리 모이스춰 로션 190ml   1  ...    충남  37.0
# 195752  14652    기타     티엔 BT21 AC컨트롤 데일리 모이스춰 로션 190ml   1  ...    경북  30.0
# 196188  38511    기타        [테스] ES-001 미세가습 360도 컬링 가습기   1  ...    충남  34.0
# 196509   9801    기타       [실리만] 실리콘 머핀 빵틀(소) 12P WSK570   1  ...    광주  36.0
# 196854  11781    기타  [실리만] 실리콘 어린이 스푼&포크 세트 WSB204 - 다홍   1  ...    서울  32.0
#
#         결제등록카드    유입경로 자녀여부   제품단가    배송기간 구매에서 배송완료까지  배송시작기간 물품구매량
# 1       농협회원조합   인스타그램    1  20583  2 days      3 days  1 days   1.0
# 7        새마을금고   인스타그램    0  20583  2 days      3 days  1 days   1.0
# 12        광주은행  네이버블로그    1  20583  2 days      3 days  1 days   1.0
# 13        국민카드  네이버블로그    1  20583  2 days      3 days  1 days   1.0
# 24        롯데카드   인스타그램    1  20583  3 days      4 days  1 days   1.0
# ...        ...     ...  ...    ...     ...         ...     ...   ...
# 195750    신한카드   인스타그램    1  18500  3 days      4 days  1 days   1.0
# 195752    우리은행   인스타그램    1  18500  2 days      3 days  1 days   1.0
# 196188    신한카드    검색광고    1  38900  3 days      4 days  1 days   1.0
# 196509  농협회원조합  네이버블로그    1   9700  2 days      3 days  1 days   1.0
# 196854    신한은행  네이버블로그    1  11900  2 days      3 days  1 days   1.0
#
# [11515 rows x 21 columns]

# %%
data['쿼터별'] = data['구매일'].apply(quater)
quater_customer = data.groupby('쿼터별').agg(count = ('쿼터별', 'count')).reset_index()
quater_customer
# Out:
#        쿼터별  count
# 0  2019 1Q  11515
# 1  2019 2Q  27450
# 2  2019 3Q  38101
# 3  2019 4Q  42436
# 4  2020 1Q  41677
# 5  2020 2Q  24883
# 6  2020 3Q  13521

# %%
sns.barplot(data=quater_customer, x = '쿼터별', y = 'count')
# Out:
# <AxesSubplot:xlabel='쿼터별', ylabel='count'>

# %%
df_penty = data[data['물품대분류'] == '팬티']
df_diaper = data[data['물품대분류'] == '기저귀']

# %%
# 이상치 제거를 위해 구매시 월령대를 6살이하로 조정
data_diaper = pd.concat([df_penty, df_diaper])
data_diaper = data_diaper[data_diaper['구매시월령(수정)'] <= 84]
data_diaper
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호    구매금액  \
# 2761    2020-02-20  2020-02-21  2020-02-23       14.0  2.018123e+14   51200
# 2762    2020-03-31  2020-04-01  2020-04-04       21.0  2.019010e+14   51200
# 2763    2020-03-08  2020-03-09  2020-03-13       14.0  2.019011e+14   51200
# 2764    2020-07-21  2020-07-22  2020-07-24       18.0  2.019011e+14   44300
# 2765    2020-02-06  2020-02-07  2020-02-09       10.0  2.019011e+14   51200
# ...            ...         ...         ...        ...           ...     ...
# 199545  2020-04-06  2020-04-07  2020-04-09        1.0  2.019121e+14  178560
# 199546  2020-04-06  2020-04-07  2020-04-10        3.0  2.019123e+14  178560
# 199557  2020-05-14  2020-05-15  2020-05-18        5.0  2.019122e+14       0
# 199569  2020-04-13  2020-04-14  2020-04-17        0.0  2.019122e+14  169200
# 199570  2020-04-12  2020-04-13  2020-04-16        0.0  2.019123e+14  169200
#
#           결제금액 물품대분류                                      상품명  성별  ...    연령  \
# 2761     37769    팬티         NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...  37.0
# 2762     34637    팬티         NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...  32.0
# 2763     33508    팬티         NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...  33.0
# 2764     22570    팬티         NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...  33.0
# 2765     34051    팬티         NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...  34.0
# ...        ...   ...                                      ...  ..  ...   ...
# 199545  123151   기저귀       하기스 네이처메이드 밤부 3단계 여아 144매(밴드형) X 3   1  ...  32.0
# 199546  121035   기저귀       하기스 네이처메이드 밤부 3단계 여아 144매(밴드형) X 3   1  ...  28.0
# 199557       0   기저귀  하기스 NEW 네이처메이드 썸머 3단계 공용 120매(밴드형)  X 3   1  ...  34.0
# 199569  111883   기저귀       NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X3   0  ...  38.0
# 199570  116186   기저귀       NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X3   1  ...  37.0
#
#        결제등록카드   유입경로 자녀여부    제품단가    배송기간  구매에서 배송완료까지  배송시작기간 물품구매량      쿼터별
# 2761     국민은행  인스타그램    1   53648  2 days       3 days  1 days   1.0  2020 1Q
# 2762     롯데카드  인스타그램    1   53648  3 days       4 days  1 days   1.0  2020 2Q
# 2763     신한은행  인스타그램    1   53648  4 days       5 days  1 days   1.0  2020 2Q
# 2764     신한은행  인스타그램    1   53648  2 days       3 days  1 days   1.0  2020 3Q
# 2765     기업은행   검색광고    1   53648  2 days       3 days  1 days   1.0  2020 1Q
# ...       ...    ...  ...     ...     ...          ...     ...   ...      ...
# 199545  새마을금고  인스타그램    1  178560  2 days       3 days  1 days   1.0  2020 2Q
# 199546   롯데카드  인스타그램    1  178560  3 days       4 days  1 days   1.0  2020 2Q
# 199557  신협중앙회   검색광고    1       0  3 days       4 days  1 days   1.0  2020 2Q
# 199569   신한은행  네이버카페    1  169200  3 days       4 days  1 days   1.0  2020 2Q
# 199570   국민은행   직접검색    1  169200  3 days       4 days  1 days   1.0  2020 2Q
#
# [62392 rows x 22 columns]

# %%
# 상품명 X 3, X 2 있는거 삭제하는방법
# data_diaper['상품명'] = data_diaper['상품명'].replace('(.*)X 3(.*)', '', regex=True).replace('(.*)X 2(.*)', '', regex=True).replace('(.*)X3(.*)', '', regex=True).replace('(.*)X2(.*)', '', regex=True)
# data_diaper[data_diaper['상품명'].str.contains('X 3')]

# %%
customer_re = data_diaper.groupby(['고객번호', '상품명']).agg(count = ('고객번호', 'count'))
customer_re[customer_re['count'] >= 2]
# Out:
#                                                    count
# 고객번호         상품명
# 2.018123e+14 하기스 네이처메이드 2단계 남아 156매(밴드형)               2
#              하기스 네이처메이드 팬티 4단계 남아 96매(팬티형)             2
#              하기스 매직팬티 컴포트핏 5단계 여아 120매(팬티형)            3
#              하기스 네이처메이드 2단계 여아 156매(밴드형)               2
#              하기스 네이처메이드 2단계 여아 156매(밴드형)               2
# ...                                                  ...
# 2.019123e+14 2020 하기스 매직 컴포트 3단계 공용 180매(밴드형)          2
#              하기스 NEW 네이처메이드 썸머팬티 3단계 공용 104매(팬티형)      2
#              하기스 네이처메이드 밤부 3단계 남아 144매(밴드형)            2
#              하기스 NEW 네이처메이드 썸머 4단계 공용 96매(밴드형)         2
#              하기스 네이처메이드 팬티 밤부 5단계 남아 88매(팬티형)          2
#
# [6400 rows x 1 columns]

# %%
data_diaper['상품명'].nunique()
# Out:
# 560

# %%
data_diaper.groupby('상품명').agg(sum_values = ('물품구매량', 'sum'))
# Out:
#                                      sum_values
# 상품명
# 2020 하기스 매직 컴포트 1단계 공용 264매                 1.0
# 2020 하기스 매직 컴포트 1단계 공용 264매(밴드형)           81.0
# 2020 하기스 매직 컴포트 1단계 공용 264매(밴드형) X2         2.0
# 2020 하기스 매직 컴포트 1단계 공용 264매(밴드형) X3         4.0
# 2020 하기스 매직 컴포트 2단계 공용 246매                12.0
# ...                                         ...
# 하기스 에어솔솔 팬티 5단계 남아용 80매(팬티형)               89.0
# 하기스 에어솔솔 팬티 5단계 여아용 80매(팬티형)               34.0
# 하기스 크린베베 순면감촉 대형 216매                       2.0
# 하기스 크린베베 순면감촉 소형 252매                       1.0
# 하기스 크린베베 순면감촉 중형 234매                       1.0
#
# [560 rows x 1 columns]

# %%
quater_data = data_diaper.groupby('쿼터별').agg(total_sales = ('결제금액', 'sum')).reset_index()
sns.barplot(data = quater_data, x = '쿼터별', y = 'total_sales')
# Out:
# <AxesSubplot:xlabel='쿼터별', ylabel='total_sales'>

# %%
quater_data
# Out:
#        쿼터별  total_sales
# 0  2019 1Q     97202485
# 1  2019 2Q    298188744
# 2  2019 3Q    498766493
# 3  2019 4Q    583553827
# 4  2020 1Q    642798147
# 5  2020 2Q    416982373
# 6  2020 3Q    184320222

# %%
quater_customer = data_diaper.groupby('쿼터별').agg(total_customer = ('고객번호', 'count')).reset_index()

# %%
quater_customer
# Out:
#        쿼터별  total_customer
# 0  2019 1Q            2156
# 1  2019 2Q            6495
# 2  2019 3Q           11217
# 3  2019 4Q           13150
# 4  2020 1Q           13943
# 5  2020 2Q            9550
# 6  2020 3Q            5881

# %%
sns.barplot(data=quater_customer, x = '쿼터별', y ='total_customer')
# Out:
# <AxesSubplot:xlabel='쿼터별', ylabel='total_customer'>

# %%
quater_user = data.groupby('쿼터별').agg(total_count = ('고객번호', 'count')).reset_index()
quater_user
# Out:
#        쿼터별  total_count
# 0  2019 1Q        11515
# 1  2019 2Q        27450
# 2  2019 3Q        38101
# 3  2019 4Q        42436
# 4  2020 1Q        41677
# 5  2020 2Q        24883
# 6  2020 3Q        13521

# %%
sns.barplot(data=quater_user, x = '쿼터별', y = 'total_count')
# Out:
# <AxesSubplot:xlabel='쿼터별', ylabel='total_count'>

# %%
level_four = df_diaper[df_diaper['상품명'].str.contains('4단계')]
level_four['구매시월령(수정)'].mean()
# Out:
# 9.99851253718657

# %%
level_five = df_diaper[df_diaper['상품명'].str.contains('5단계')]
level_five['구매시월령(수정)'].mean()
# Out:
# 15.444139194139193

# %%
# 배송기간 퍼센트
delay_deliver = data[data['배송기간'] > '2 days']
delay_deliver_percent = len(delay_deliver) / len(data) * 100
delay_deliver_percent
# Out:
# 30.077712029581676

# %%
#배송 지연 퍼센트 Pit plot
x = ['배송 지연', '정상 배송']
y = [round(delay_deliver_percent, 2), 100 - round(delay_deliver_percent, 2)]

plt.title("전체 배송지연 비율")
plt.pie(y, labels=x, autopct='%1.1f%%')
plt.show()

# %%
first_diaper = data_diaper[data_diaper['상품명'].str.contains('1단')]
first_diapers = first_diaper[first_diaper['구매시월령(수정)'] <= 1]
mean_first = first_diapers['구매시월령(수정)'].mean()
outlier_first = first_diaper[first_diaper['구매시월령(수정)'] >= 1]
outlier_first['구매시월령(수정)']  = round(mean_first, 0)
outlier_first
# Out:
# C:\Users\Song\AppData\Local\Temp\ipykernel_21992\1458536627.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outlier_first['구매시월령(수정)']  = round(mean_first, 0)
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호    구매금액  \
# 157974  2020-07-01  2020-07-02  2020-07-04        0.0  2.019010e+14   48900
# 157975  2020-07-09  2020-07-10  2020-07-12        0.0  2.019010e+14   48900
# 157976  2020-07-20  2020-07-21  2020-07-25        0.0  2.019011e+14   48900
# 157977  2020-07-09  2020-07-10  2020-07-13        0.0  2.019011e+14   48900
# 157978  2020-07-24  2020-07-25  2020-07-28        0.0  2.019011e+14   48900
# ...            ...         ...         ...        ...           ...     ...
# 196268  2019-04-09  2019-04-10  2019-04-13        0.0  2.019033e+14   52080
# 196678  2020-02-11  2020-02-12  2020-02-16        0.0  2.019082e+14  104640
# 197479  2020-01-12  2020-01-13  2020-01-16        0.0  2.019051e+14  214500
# 198078  2020-01-09  2020-01-10  2020-01-12        0.0  2.019031e+14  143000
# 198079  2020-04-18  2020-04-19  2020-04-21        0.0  2.019091e+14  143000
#
#           결제금액 물품대분류                                          상품명  성별  ...  \
# 157974   29084    팬티              NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)   1  ...
# 157975   21224    팬티              NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)   1  ...
# 157976   25586    팬티              NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)   1  ...
# 157977   21224    팬티              NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)   1  ...
# 157978   21224    팬티              NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)   1  ...
# ...        ...   ...                                          ...  ..  ...
# 196268   35046   기저귀  [쿠폰적용가37,490원] 하기스 매직핏 기저귀 1단계 공용 210매(밴드형)   1  ...
# 196678   72581   기저귀               하기스 네이처메이드 1단계 공용 186매(밴드형) X2   1  ...
# 197479  125883   기저귀          2020 하기스 매직 컴포트 1단계 공용 264매(밴드형) X3   1  ...
# 198078   89917   기저귀          2020 하기스 매직 컴포트 1단계 공용 264매(밴드형) X2   1  ...
# 198079   98688   기저귀          2020 하기스 매직 컴포트 1단계 공용 264매(밴드형) X2   1  ...
#
#           연령  결제등록카드    유입경로 자녀여부    제품단가    배송기간  구매에서 배송완료까지  배송시작기간 물품구매량  \
# 157974  30.0  농협회원조합    검색광고    0   50071  2 days       3 days  1 days   1.0
# 157975  34.0  농협회원조합  네이버블로그    1   50071  2 days       3 days  1 days   1.0
# 157976  34.0  농협회원조합    검색광고    1   50071  4 days       5 days  1 days   1.0
# 157977  34.0    신한은행  네이버블로그    1   50071  3 days       4 days  1 days   1.0
# 157978  34.0    신한은행  네이버블로그    1   50071  3 days       4 days  1 days   1.0
# ...      ...     ...     ...  ...     ...     ...          ...     ...   ...
# 196268  35.0    국민은행   네이버카페    1   52080  3 days       4 days  1 days   1.0
# 196678  30.0    롯데카드   인스타그램    1  104640  4 days       5 days  1 days   1.0
# 197479  40.0    하나은행    검색광고    0  214500  3 days       4 days  1 days   1.0
# 198078  38.0    국민은행   네이버카페    1  143000  2 days       3 days  1 days   1.0
# 198079  30.0    신한은행    지인추천    1  143000  2 days       3 days  1 days   1.0
#
#             쿼터별
# 157974  2020 3Q
# 157975  2020 3Q
# 157976  2020 3Q
# 157977  2020 3Q
# 157978  2020 3Q
# ...         ...
# 196268  2019 2Q
# 196678  2020 1Q
# 197479  2020 1Q
# 198078  2020 1Q
# 198079  2020 2Q
#
# [784 rows x 22 columns]

# %%
second_diaper = data_diaper[data_diaper['상품명'].str.contains('2단')]
second_diapers = second_diaper[second_diaper['구매시월령(수정)'] <= 2]
mean_second = second_diapers['구매시월령(수정)'].mean()
mean_second
# first_diapers = first_diaper[first_diaper['구매시월령(수정)'] <= 1]
# mean_first = first_diapers['구매시월령(수정)'].mean()
# outlier_first = first_diaper[first_diaper['구매시월령(수정)'] >= 1]
# outlier_first['구매시월령(수정)']  = round(mean_first, 0)
# outlier_first
# Out:
# 0.8639301874595993

# %%
# child_data = data_diaper[data_diaper['구매시월령(수정)'] >= 0]
excpet_child = data_diaper[~data_diaper['상품명'].str.contains('핑크퐁')]
kids_men = excpet_child[excpet_child['상품명'].str.contains('남아')]
kids_girl = excpet_child[excpet_child['상품명'].str.contains('여아')]
kids_common = excpet_child[excpet_child['상품명'].str.contains('공용')]
kids_men['child_sex'] = '남아'
kids_girl['child_sex'] = '여아'
kids_common['child_sex'] = '공용'
child_df = pd.concat([kids_men, kids_girl, kids_common])
child_df
# Out:
# C:\Users\Song\AppData\Local\Temp\ipykernel_21992\330329113.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kids_men['child_sex'] = '남아'
# C:\Users\Song\AppData\Local\Temp\ipykernel_21992\330329113.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kids_girl['child_sex'] = '여아'
# C:\Users\Song\AppData\Local\Temp\ipykernel_21992\330329113.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kids_common['child_sex'] = '공용'
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호    구매금액  \
# 2761    2020-02-20  2020-02-21  2020-02-23       14.0  2.018123e+14   51200
# 2762    2020-03-31  2020-04-01  2020-04-04       21.0  2.019010e+14   51200
# 2763    2020-03-08  2020-03-09  2020-03-13       14.0  2.019011e+14   51200
# 2764    2020-07-21  2020-07-22  2020-07-24       18.0  2.019011e+14   44300
# 2765    2020-02-06  2020-02-07  2020-02-09       10.0  2.019011e+14   51200
# ...            ...         ...         ...        ...           ...     ...
# 199461  2020-04-20  2020-04-21  2020-04-23        5.0  2.019102e+14  116000
# 199530  2019-11-27  2019-11-28  2019-12-01        0.0  2.019113e+14  163440
# 199557  2020-05-14  2020-05-15  2020-05-18        5.0  2.019122e+14       0
# 199569  2020-04-13  2020-04-14  2020-04-17        0.0  2.019122e+14  169200
# 199570  2020-04-12  2020-04-13  2020-04-16        0.0  2.019123e+14  169200
#
#           결제금액 물품대분류                                      상품명  성별  ...  \
# 2761     37769    팬티         NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...
# 2762     34637    팬티         NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...
# 2763     33508    팬티         NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...
# 2764     22570    팬티         NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...
# 2765     34051    팬티         NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)   1  ...
# ...        ...   ...                                      ...  ..  ...
# 199461   84830   기저귀             그린핑거 기저귀 3단계 공용 132매(밴드형) X2   1  ...
# 199530  106692   기저귀        하기스 네이처메이드 밤부 1단계 공용 186매(밴드형) X3   0  ...
# 199557       0   기저귀  하기스 NEW 네이처메이드 썸머 3단계 공용 120매(밴드형)  X 3   1  ...
# 199569  111883   기저귀       NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X3   0  ...
# 199570  116186   기저귀       NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X3   1  ...
#
#         결제등록카드    유입경로  자녀여부    제품단가    배송기간  구매에서 배송완료까지  배송시작기간 물품구매량  \
# 2761      국민은행   인스타그램     1   53648  2 days       3 days  1 days   1.0
# 2762      롯데카드   인스타그램     1   53648  3 days       4 days  1 days   1.0
# 2763      신한은행   인스타그램     1   53648  4 days       5 days  1 days   1.0
# 2764      신한은행   인스타그램     1   53648  2 days       3 days  1 days   1.0
# 2765      기업은행    검색광고     1   53648  2 days       3 days  1 days   1.0
# ...        ...     ...   ...     ...     ...          ...     ...   ...
# 199461    국민카드   인스타그램     0  116000  2 days       3 days  1 days   1.0
# 199530    우리은행  네이버블로그     0  163440  3 days       4 days  1 days   1.0
# 199557   신협중앙회    검색광고     1       0  3 days       4 days  1 days   1.0
# 199569    신한은행   네이버카페     1  169200  3 days       4 days  1 days   1.0
# 199570    국민은행    직접검색     1  169200  3 days       4 days  1 days   1.0
#
#             쿼터별 child_sex
# 2761    2020 1Q        남아
# 2762    2020 2Q        남아
# 2763    2020 2Q        남아
# 2764    2020 3Q        남아
# 2765    2020 1Q        남아
# ...         ...       ...
# 199461  2020 2Q        공용
# 199530  2019 4Q        공용
# 199557  2020 2Q        공용
# 199569  2020 2Q        공용
# 199570  2020 2Q        공용
#
# [61623 rows x 23 columns]

# %%
first_diaper = child_df[child_df['상품명'].str.contains('1단')]
second_diaper = child_df[child_df['상품명'].str.contains('2단')]
third_diaper = child_df[child_df['상품명'].str.contains('3단')]
forth_diaper = child_df[child_df['상품명'].str.contains('4단')]
fifth_diaper = child_df[child_df['상품명'].str.contains('5단')]

# %%
first_diaper['기저귀 단계'] = 1
second_diaper['기저귀 단계'] = 2
third_diaper['기저귀 단계'] = 3
forth_diaper['기저귀 단계'] = 4
fifth_diaper['기저귀 단계'] = 5
# Out:
# C:\Users\Song\AppData\Local\Temp\ipykernel_21992\2582838680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_diaper['기저귀 단계'] = 1
# C:\Users\Song\AppData\Local\Temp\ipykernel_21992\2582838680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_diaper['기저귀 단계'] = 2
# C:\Users\Song\AppData\Local\Temp\ipykernel_21992\2582838680.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   third_diaper['기저귀 단계'] = 3
# C:\Users\Song\AppData\Local\Temp\ipykernel_21992\2582838680.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forth_diaper['기저귀 단계'] = 4
# C:\Users\Song\AppData\Local\Temp\ipykernel_21992\2582838680.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifth_diaper['기저귀 단계'] = 5

# %%
sep_diaper = pd.concat([first_diaper, second_diaper, third_diaper, forth_diaper, fifth_diaper])
sep_diaper
# Out:
#                구매일       배송시작일       배송완료일  구매시월령(수정)          고객번호    구매금액  \
# 157974  2020-07-01  2020-07-02  2020-07-04       13.0  2.019010e+14   48900
# 157975  2020-07-09  2020-07-10  2020-07-12        5.0  2.019010e+14   48900
# 157976  2020-07-20  2020-07-21  2020-07-25       21.0  2.019011e+14   48900
# 157977  2020-07-09  2020-07-10  2020-07-13       26.0  2.019011e+14   48900
# 157978  2020-07-24  2020-07-25  2020-07-28       26.0  2.019011e+14   48900
# ...            ...         ...         ...        ...           ...     ...
# 198406  2020-01-20  2020-01-21  2020-01-23        6.0  2.019063e+14  130400
# 198407  2020-01-19  2020-01-20  2020-01-22        5.0  2.019100e+14  130400
# 198408  2020-01-19  2020-01-20  2020-01-22        7.0  2.019100e+14  130400
# 198409  2020-01-19  2020-01-20  2020-01-23       10.0  2.019111e+14  130400
# 199090  2019-12-03  2019-12-04  2019-12-07       33.0  2.019062e+14   92800
#
#          결제금액 물품대분류                                  상품명  성별  ...    유입경로  \
# 157974  29084    팬티      NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)   1  ...    검색광고
# 157975  21224    팬티      NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)   1  ...  네이버블로그
# 157976  25586    팬티      NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)   1  ...    검색광고
# 157977  21224    팬티      NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)   1  ...  네이버블로그
# 157978  21224    팬티      NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)   1  ...  네이버블로그
# ...       ...   ...                                  ...  ..  ...     ...
# 198406  82080   기저귀  2020 하기스 매직 컴포트 5단계 공용 126매(밴드형) X2   1  ...   인스타그램
# 198407  86400   기저귀  2020 하기스 매직 컴포트 5단계 공용 126매(밴드형) X2   1  ...    지인추천
# 198408  86400   기저귀  2020 하기스 매직 컴포트 5단계 공용 126매(밴드형) X2   1  ...   인스타그램
# 198409  84384   기저귀  2020 하기스 매직 컴포트 5단계 공용 126매(밴드형) X2   1  ...   인스타그램
# 199090  61341   기저귀         하기스 맥스드라이 5단계 공용 92매(밴드형) X2   1  ...  네이버블로그
#
#        자녀여부    제품단가    배송기간 구매에서 배송완료까지  배송시작기간  물품구매량      쿼터별 child_sex  \
# 157974    0   50071  2 days      3 days  1 days    1.0  2020 3Q        공용
# 157975    1   50071  2 days      3 days  1 days    1.0  2020 3Q        공용
# 157976    1   50071  4 days      5 days  1 days    1.0  2020 3Q        공용
# 157977    1   50071  3 days      4 days  1 days    1.0  2020 3Q        공용
# 157978    1   50071  3 days      4 days  1 days    1.0  2020 3Q        공용
# ...     ...     ...     ...         ...     ...    ...      ...       ...
# 198406    1  130400  2 days      3 days  1 days    1.0  2020 1Q        공용
# 198407    1  130400  2 days      3 days  1 days    1.0  2020 1Q        공용
# 198408    1  130400  2 days      3 days  1 days    1.0  2020 1Q        공용
# 198409    1  130400  3 days      4 days  1 days    1.0  2020 1Q        공용
# 199090    0   92800  3 days      4 days  1 days    1.0  2020 1Q        공용
#
#        기저귀 단계
# 157974      1
# 157975      1
# 157976      1
# 157977      1
# 157978      1
# ...       ...
# 198406      5
# 198407      5
# 198408      5
# 198409      5
# 199090      5
#
# [59261 rows x 24 columns]

# %%
# 팬티 : 0, 기저귀 : 1

sep_diaper['물품대분류'] = sep_diaper['물품대분류'].replace('팬티', 0).replace('기저귀', 1)
sep_diaper.columns
# Out:
# Index(['구매일', '배송시작일', '배송완료일', '구매시월령(수정)', '고객번호', '구매금액', '결제금액', '물품대분류',
#        '상품명', '성별', '결혼유무', '거주지역', '연령', '결제등록카드', '유입경로', '자녀여부', '제품단가',
#        '배송기간', '구매에서 배송완료까지', '배송시작기간', '물품구매량', '쿼터별', 'child_sex', '기저귀 단계'],
#       dtype='object')

# %%
sep_diaper.groupby('기저귀 단계').agg(mean_age = ('구매시월령(수정)', 'mean'), max_age = ('구매시월령(수정)', 'max'), min_age = ('구매시월령(수정)', 'min'), count = ('구매시월령(수정)', 'count'))
# Out:
#          mean_age  max_age  min_age  count
# 기저귀 단계
# 1        2.948824     84.0      0.0   3146
# 2        3.244403     83.0      0.0  11747
# 3        6.216593     84.0      0.0  20430
# 4       10.797760     84.0      0.0  16248
# 5       15.826008     84.0      0.0   7690

# %%
sep_diaper.to_csv('diaper.csv')

# %%
count_customer = sep_diaper.groupby(['고객번호', '구매일']).agg(count = ('고객번호', 'count'))
# count_customer = count_customer[count_customer['count'] >= 2]
count_customer
# Out:
#                          count
# 고객번호         구매일
# 2.018123e+14 2020-02-20      1
#              2019-05-13      1
#              2019-05-10      1
#              2019-07-29      1
#              2019-07-23      1
# ...                        ...
# 2.019123e+14 2020-04-19      1
#              2019-12-29      1
#              2020-02-01      1
#              2020-07-18      1
#              2019-12-29      1
#
# [57202 rows x 1 columns]

# %%
# Out:
# Empty DataFrame
# Columns: [구매일, 배송시작일, 배송완료일, 구매시월령(수정), 고객번호, 구매금액, 결제금액, 물품대분류, 상품명, 성별, 결혼유무, 거주지역, 연령, 결제등록카드, 유입경로, 자녀여부, 제품단가, 배송기간, 구매에서 배송완료까지, 배송시작기간, 물품구매량, 쿼터별, child_sex, 기저귀 단계]
# Index: []
#
# [0 rows x 24 columns]
