# %% [markdown]
# # 설정
# ## Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import mglearn
import matplotlib.pyplot as plt
# %matplotlib inline
import platform
import os
# 운영체제별 한글 폰트 설정

if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정
# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 데이터 불러오기

# %%
member_data = pd.read_csv('Member_data02.csv')
product_data = pd.read_csv('Product_data.csv')
sales_data = pd.read_csv('Sales_data02.csv', low_memory=False)

# %% [markdown]
# ## 미리보기
# ### 데이터프레임

# %%
product_data.head()

# %%
sales_data.head()

# %%
member_data.head()

# %% [markdown]
# ### Plot

# %% [markdown]
# # 데이터 전처리
# ## 공백 삭제

# %%
#NaN 값이 포함된 모든 행을 삭제합니다.
member_data_2_1 = member_data.dropna(axis = 0)
# member_data_2_1

# %%
member_data['ID'] = member_data['ID'].astype(str)

# %%
member_data
# Out:
#                       ID   성별 결혼유무 거주지역    연령 결제등록카드    유입경로 자녀여부
# 0      201812310749735.0    여   기혼   인천  37.0   국민은행   인스타그램  Yes
# 1      201812310749770.0    여   기혼   제주  33.0   국민은행    검색광고  Yes
# 2      201812310749771.0    여   기혼   부산  32.0   하나은행  네이버블로그  Yes
# 3      201812310749774.0    여   미혼   경남  34.0   기업은행    지인추천   No
# 4      201812310749780.0    여   기혼   서울  32.0   신한은행    직접검색  Yes
# ...                  ...  ...  ...  ...   ...    ...     ...  ...
# 81355                nan  NaN  NaN  NaN   NaN    NaN     NaN  NaN
# 81356                nan  NaN  NaN  NaN   NaN    NaN     NaN  NaN
# 81357                nan  NaN  NaN  NaN   NaN    NaN     NaN  NaN
# 81358                nan  NaN  NaN  NaN   NaN    NaN     NaN  NaN
# 81359                nan  NaN  NaN  NaN   NaN    NaN     NaN  NaN
#
# [81360 rows x 8 columns]

# %%
sales_data.iloc[:3,:6]
# Out:
#               주문번호         구매일       배송시작일       배송완료일  구매시월령(수정)  \
# 0  201905052342970  2019-05-06  2019-05-07  2019-05-11        4.0
# 1  202002203424450  2020-02-20  2020-02-21  2020-02-23       14.0
# 2  201902282095385  2019-02-28  2019-03-01  2019-03-05        NaN
#
#                 고객번호
# 0  201812310749735.0
# 1  201812310749735.0
# 2  201812310749770.0

# %% [markdown]
# ## 머지
# ### sales 와 member 머지

# %%
# Merge를 위한 형 변환
sales_data['고객번호'] = sales_data['고객번호'].astype('float')

# %%
df = pd.merge(sales_data, member_data, right_on='ID', left_on = '고객번호')
merge_outer = pd.merge(sales_data, member_data, right_on='ID', left_on = '고객번호', how = 'left')

# %%
# df
# merge_outer

# %%
merge_outer['ID'] = merge_outer['ID'].astype('str')

# %%
product_data['total'] = product_data['물품판매량'] * product_data['제품단가']

# %% [markdown]
# ### product 를 머지

# %%
product = product_data[['물품대분류', '상품명', '제품단가']]

# %%
sales_data.iloc[:,6:]
# Out:
#          구매금액   결제금액 물품대분류                                        상품명
# 0       25800  16314  더블하트              더블하트 SofTouch 모유실감 젖꼭지 M (2입)
# 1       51200  37769    팬티           NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)
# 2        5610   3800   FMC                     크리넥스？키즈용？화장지？3겹？27m 8롤
# 3       59520  47922   기저귀             하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)
# 4       50640  39788   기저귀            하기스 에어솔솔 썸머기저귀 3단계 공용 144매(밴드형)
# ...       ...    ...   ...                                        ...
# 199994  11700   9240   FMC        크리넥스 뽑아쓰는 키친타월 펭수에디션 140매 X 4입 (EA)
# 199995   3000   3000   체험팩                                    맘큐 허그박스
# 199996   5900   5841   체험팩  NEW 하기스 맥스드라이 팬티 3단계 공용 20매(팬티형/체험팩) (EA)
# 199997   3000   3000   체험팩                                    맘큐 허그박스
# 199998   8500   8500    기타                            [먼치킨] 멀티 젖병솔 세트
#
# [199999 rows x 4 columns]

# %%
df = df.merge(product, on = ['물품대분류', '상품명'])

# %% [markdown]
# ## 형 변환

# %%
df['배송시작일']=pd.to_datetime(df['배송시작일'],format = '%Y-%m-%d')
df['구매일']=pd.to_datetime(df['구매일'],format = '%Y-%m-%d')
df['배송완료일']=pd.to_datetime(df['배송완료일'],format = '%Y-%m-%d')

# %%
# Yes : 1, No : 0
df['자녀여부'] = df['자녀여부'].replace('Yes', 1).replace('No', 0)

# %%
# 여성 : 1, 남성 : 0
# 기혼 : 1, 미혼 : 0
# 출산예정 : 0
df['성별'] = df['성별']. replace('여', 1).replace('남', 0)
df['결혼유무'] = df['결혼유무'].replace('기혼', 1).replace('미혼', 0)
df['고객번호'].astype('float64')
df['구매시월령(수정)'] = df['구매시월령(수정)'].fillna(0)
# df[df['구매시월령(수정)'] < 0]

# %%
df.iloc[0:3,[0,1,2,3,9,10]]
# Out:
#          구매일      배송시작일      배송완료일  구매시월령(수정)  성별  결혼유무
# 0 2019-05-06 2019-05-07 2019-05-11        4.0   1     1
# 1 2019-01-01 2019-01-02 2019-01-04        1.0   1     1
# 2 2019-04-14 2019-04-15 2019-04-18        2.0   1     1

# %% [markdown]
# ## 계산된 칼럼 추가
# ### 배송기간

# %%
df['배송기간'] = df['배송완료일'] -df['배송시작일']
df['구매에서 배송완료까지'] = df['배송완료일']- df['구매일']
df['배송시작기간'] = df['배송시작일'] - df['구매일']

df.drop(['주문번호', 'ID'], axis = 1, inplace = True)

# %% [markdown]
# ## 월령 마이너스 문제해결?

# %%
def minus_change(i):
    if i < 0:
        return 0
    else:
        return i

df['구매시월령(수정)'] = df['구매시월령(수정)'].apply(minus_change)

# %% [markdown]
# # Plot

# %%
babymonth_boxplot = sales_data.boxplot(column = ['구매시월령(수정)'])
babymonth_boxplot
# Out:
# <AxesSubplot:>

# %%
babymonth_histplot = sns.histplot(sales_data, x="구매시월령(수정)")
babymonth_histplot
# Out:
# <AxesSubplot:xlabel='구매시월령(수정)', ylabel='Count'>

# %%
df['물품대분류'].unique()
# Out:
# array(['더블하트', '팬티', 'FMC', '기저귀', '체험팩', 'FC', '기타', '물티슈', 'SKC', 'SrC'],
#       dtype=object)

# %% [markdown]
# # 팀 전달

# %%
poham.to_csv('유아용품.csv')
mipoham.to_csv('유아용품 외.csv')

# %%
mipoham['상품명'].count()
# Out:
# 38556

# %% [markdown]
# ## 유아용품 추출

# %%
# 상품명의 키워드를 기준으로 유아용품 분류
keyword = '유아|맘|모유|엄마|하기스|젖|아기|아가|베이비|콧물|그린핑거|핑크퐁|더블하트|누들앤부|출산|도담도담|드시모네|디어에코|라밀로우|리틀누|마마|마더|수유|맘마|매직캔|이유식|먼치킨|싸개|메릴린|몽슈레|신생아|유모차|턱받이|베베|보보앤부|본토이|브라이트|브리카|비박스|비츠|뽀드|뿌띠|쁘띠|치발기|페어리|야마토야|에르고|에불로보|오볼|원펀|율그란|카시트|필리앤|스페셜기프트SET|마밍|릴리유|굿나이트|키즈|듀플로'
poham = df[df['상품명'].str.contains(keyword)]
mipoham = df[~df['상품명'].str.contains(keyword)]

# %% [markdown]
# 키워드를 구분한 기준은:
# 1. 그냥 딱 봐도 아기 관련된 키워드
# 2. 브랜드명을 구글링 했을때, 상품 홍보이미지로 나오는 인물이 유아인가, 어린이인가?

# %% [markdown]
# ## 대분류 제거

# %%
# list_4_2 = poham['물품대분류'].unique()
bigkind_count = pd.DataFrame()
list1 = df['물품대분류'].unique()
for a in list1:
    result1 = df['물품대분류'][df['물품대분류'] == a].count()
    bigkind_count.at[a,'df'] = result1
    result2 = poham['물품대분류'][poham['물품대분류'] == a].count()
    bigkind_count.at[a,'유아용품'] = result2

# %%
bigkind_count.astype(int)
# Out:
#          df   유아용품
# 더블하트  37228  37222
# 팬티    27581  27581
# FMC   25950   1880
# 기저귀   35318  35238
# 체험팩   35390  35390
# FC    12424    126
# 기타     7867   4872
# 물티슈    8446   8446
# SKC    9365   9361
# SrC      14     10

# %% [markdown]
# 해석:
# 모든 물품대분류에 유아용품이 들어간 것을 알 수 있다.
# FMC와 FC에는 그 비율이 낮으나 무시할 수 없는 숫자라는 개인적 의견이며,
# 기타의 유아용품 비율은 3/4 정도로써, 비-유아용품이 많이 섞여있다는 것을 알 수 있다.
# 따라서 물품대분류는 유아용품을 구분할 기준으로써 적합하지 않다!

# %% [markdown]
# ## 재분류 칼럼 추가

# %%
#product_data에서 키워드를 포함하는 제품 리스트 추출
poham_pd = product_data[product_data['상품명'].str.contains(keyword)]
mipoham_pd = product_data[~product_data['상품명'].str.contains(keyword)]
poham_new = pd.DataFrame()
poham_df1 = poham_pd
poham_df1['재분류'] = ''
# Out:
# C:\Users\mrshi\AppData\Local\Temp\ipykernel_18740\2380216728.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poham_df1['재분류'] = ''

# %%
# 재분류 할 키워드 목록
function = {'의약외품': '드시모네|열내림',
            '기저귀': '기저귀|하기스',            
            '이유식': '이유식|맘마',
            '임신전후': '마더|맘스|출산|허그박스|니플',
            '가구': '야마토야|의자',
            '아기띠': '아기띠|에르고',            
            '살균기': '살균',
            '수유': '수유|모유|흡인기|유두보호기',
            '젖병': '젖병|젖꼭지브러쉬|젖꼭지 브러쉬|스파우트',
            '치발기': '치발|젖꼭지',            
            '물티슈': '콧물|물티슈|마이비데|릴리유',
            '화장지': '화장지',
            '차량용품': '카시트|차량|브리카',
            '유모차': '유모차',
            '장난감': '장난감|듀플로|피아노|핸드폰|스페셜기프트SET|뿌띠슈|본토이|브라이트|오볼|디즈니|베이비아인슈타인',
            '아기의류': '싸개|받이|배냇|외출용 필수 3종세트|스와들|양말|손수건|스카프|토시|덧신|슈즈|디어에코|내의|조끼|슈트|내복|장갑|목도리',
            '침구류': '방수요|베개|이불|블랭킷',
            '식기': '컵|스푼|몰드|플레이트|접시|식판|밀폐용기|식기|빨대브러쉬|빨대 브러쉬',
            '마스크': '마스크',
            '위생용품': '샴푸|로션|소독|리틀마마|오일|크림|손톱|유치브러쉬|면봉|핀셋|그린핑거|워시|손가락칫솔|손가락 칫솔',
            '기저귀': '기저귀|하기스',
            '안전': '보호대',
            '목욕': '샤워볼|타올|욕조|목욕놀이|목욕|탕온계',
            '세탁': '섬유',
            '악세서리': '헤어|머리핀|선글라스',
            '인형': '인형',
            '바운서': '바운서',
            '식품': '치즈|유기농',
            '물놀이': '보행기 튜브|슈즈|비치|선밤|선크림|선팩트|물놀이|물총',
            '팬티': '굿나이트'}

# %%
# for문 이용, 위의 딕셔너리를 키워드로 하나씩 분류한다.
test2 = pd.DataFrame()
for key, value in function.items():
    test1 = poham_df1[poham_df1['상품명'].str.contains(value)]
    index = list(test1.index)
    for a in index:
        test1.at[a,'재분류'] = key
        poham_df1 = poham_df1.drop(index=a)
    test2 = pd.concat([test1,test2])

# %%
# 미분류 된 상품명들도 "재분류" 칼럼 값을 입력해준다.
for a in list(poham_df1.index):
    poham_df1.at[a,'재분류'] = '미분류'

# %%
# 분류 완료된 DataFrame
poham_new = pd.concat([test2,poham_df1])
# poham_new

# %%
# 머지
product1 = poham_new[['물품대분류', '상품명', '재분류']]
df1 = df.merge(product1, on = ['물품대분류', '상품명'])

# %%
# poham_df1.sort_values(by='물품판매량', ascending=False)

# %%
# poham_pd[poham_pd['상품명'].str.contains('마그마그')]

# %% [markdown]
# ## ipynb 정렬

# %% [markdown]
# ## Plot

# %% [markdown]
# ### 마진

# %%
df2 = df1.assign(구매금액_제품단가 = lambda x: (x['구매금액']-x['제품단가']))

# %%
plt.figure(figsize=(15,7))
values = df2.groupby(['재분류'])['구매금액_제품단가'].sum().sort_values(ascending=False)
labels = values.index

plt.title('마진', fontdict={'fontsize':15})
plt.style.use('bmh')
margin = plt.bar(labels, values, width=0.7)
plt.xticks(rotation=45)
plt.yticks(fontsize=15)
# plt.grid(True, axis='x')
plt.savefig('재분류 - 마진(top7).png', dpi=300)
plt.show()

# %%
# df2[df2['재분류']!=labels1]['구매금액_제품단가'].sum()
df2[df2['재분류']!=labels1]['재분류'].unique()
# Out:
# array(['수유', '화장지', '임신전후', '치발기', '아기의류', '식기', '젖병', '물티슈', '위생용품',
#        '목욕', '이유식', '세탁', '장난감', '마스크', '차량용품', '미분류', '의약외품', '물놀이',
#        '식품', '팬티', '아기띠', '인형', '유모차', '악세서리', '침구류', '가구', '안전', '살균기'],
#       dtype=object)

# %%
plt.figure(figsize=(13,5))

value1 = df2.groupby(['재분류'])['구매금액_제품단가'].sum().sort_values(ascending=False)[0]
labels1 = df2.groupby(['재분류'])['구매금액_제품단가'].sum().sort_values(ascending=False).index[0]
value2 = df2[df2['재분류']!=labels1]['구매금액_제품단가'].sum()
labels2 = '그 외'

plt.title('마진', fontdict={'fontsize':15})
plt.style.use('bmh')
margin2 = plt.bar([labels1,labels2], [value1,value2], width=0.7)
plt.xticks(rotation=45)
plt.yticks(fontsize=15)
# plt.grid(True, axis='x')
# plt.savefig('재분류 - 마진.png', dpi=300)
plt.show()

# %%
labels = '기저귀', '그 외'
sizes = [value1, value2]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('마진', fontdict={'fontsize':15})

plt.savefig('재분류 - 마진 pie plot.png', dpi=300)
plt.show()

# %% [markdown]
# ### 구매금액

# %%
plt.figure(figsize=(13,7))
values = df2.groupby(['재분류'])['구매금액'].sum().sort_values(ascending=False).iloc[:10]
labels = values.index

plt.title('총 구매금액', fontdict={'fontsize':15})
plt.style.use('bmh')
purchase_sum = plt.bar(labels, values, width=0.7)
plt.xticks(rotation=45)
plt.yticks(fontsize=15)
# plt.grid(True, axis='x')
plt.savefig('재분류 - 총 구매금액.png', dpi=300)
plt.show()

# 상위 10
purchase_top10 = values.index[0:10]

# %%
plt.figure(figsize=(13,7))

value1 = df2.groupby(['재분류'])['구매금액'].sum().sort_values(ascending=False)[0]
labels1 = df2.groupby(['재분류'])['구매금액'].sum().sort_values(ascending=False).index[0]
value2 = df2[df2['재분류']!=labels1]['구매금액'].sum()
labels2 = '그 외'

plt.title('총 구매금액', fontdict={'fontsize':15})
plt.style.use('bmh')
purchase_sum2 = plt.bar([labels1,labels2], [value1,value2], width=0.7)
plt.xticks(rotation=45)
plt.yticks(fontsize=15)
# plt.grid(True, axis='x')
plt.savefig('재분류 - 총 구매금액.png', dpi=300)
plt.show()

# %% [markdown]
# ### 할인율 (구매금액-결제금액)

# %%
plt.figure(figsize=(13,7))
values = df2.groupby('재분류').apply(lambda df2,a,b: sum(df2[a] - df2[b]),'구매금액', '결제금액').sort_values(ascending=False)
labels = values.index

plt.title('총 할인금액 (구매금액-결제금액)', fontdict={'fontsize':15})
plt.style.use('bmh')
discount = plt.bar(labels, values, width=0.7)
plt.xticks(rotation=45)
plt.yticks(fontsize=15)
# plt.grid(True, axis='x')
plt.savefig('재분류 - 총 할인금액.png', dpi=300)
plt.show()

# %% [markdown]
# 해석:
# 구매금액과 할인금액의 그래프가 큰 차이를 보이지 않는다.
# 품목에 대한 할인은 없다고 보여진다.

# %% [markdown]
# ### 구매금액 변화 (1주 간격)

# %%
x = df2.groupby(pd.Grouper(key='구매일', freq='W'))['구매일'].count().index
y = df2.groupby(pd.Grouper(key='구매일', freq='W'))['구매금액'].sum()
week = pd.date_range('2019-01-01', '2020-10-01', freq='W').to_series()
month = pd.date_range('2019-01-01', '2020-10-01', freq='M').to_series()


plt.figure(figsize=(13,7))
plt.title('총 구매금액 변화(날짜순, Top10)', fontdict={'fontsize':20})
for a in purchase_top10:
    x = df2[df2['재분류'] == a].groupby(pd.Grouper(key='구매일', freq='W'))['구매일'].count().index
    y = df2[df2['재분류'] == a].groupby(pd.Grouper(key='구매일', freq='W'))['구매금액'].sum()
    plt.plot(x,y, label=a)
plt.xticks(month, rotation=45)
plt.xlabel('날짜(주)',fontdict={'fontsize':15})
plt.legend()
plt.savefig('재분류 - 날짜별 결제금액.png', dpi=300)
plt.show()

# %% [markdown]
# ### 지연배송 건수

# %%
# df2['배송기간'] = df2['배송기간'].dt.days
# df_delay = df2[df2['배송기간']>=3]
pivot = pd.pivot_table(data = df_delay, index = '재분류', columns = '배송기간', values = '구매일', aggfunc = 'count')
pivot = pivot.sort_values(by=3, ascending=False)

# %%
pivot = pivot.iloc[:6]

# %%
pivot.plot.bar(figsize=(7,5), title='지연배송 건수')
plt.savefig('지연배송 건수.png')

# %% [markdown]
# ## 기저귀 단계별 분류

# %%
diper1 = df2[df2['상품명'].str.contains('기저귀')]
diper_level = ['이른둥이', '1단계', '2단계', '3단계', '4단계', '5단계', '6단계']
diper2 = pd.DataFrame()

for i in diper_level:
    diper3 = diper1[diper1['상품명'].str.contains(i)]
    for a in diper3.index:
        diper3.at[a,'기저귀 단계'] = i
    diper2 = pd.concat([diper2,diper3])
diper_fin = diper2

# %%
diper_fin.tail(3)
# Out:
#               구매일      배송시작일      배송완료일  구매시월령(수정)          고객번호   구매금액  \
# 155414 2019-04-09 2019-04-10 2019-04-13       69.0  2.019012e+14  65880
# 153577 2020-06-23 2020-06-24 2020-06-26       17.0  2.019012e+14  49900
# 153578 2020-04-22 2020-04-23 2020-04-25       15.0  2.019023e+14  58000
#
#          결제금액 물품대분류                                         상품명  성별  ...  \
# 155414  42253   기저귀  [쿠폰적용가42,680원] 하기스 매직핏기저귀 5단계 공용 138매(밴드형)   1  ...
# 153577  38920   기저귀                    그린핑거 기저귀 6단계 공용 62매(팬티형)   1  ...
# 153578  39969   기저귀                    그린핑거 기저귀 6단계 공용 62매(팬티형)   1  ...
#
#         결제등록카드   유입경로  자녀여부   제품단가   배송기간  구매에서 배송완료까지  배송시작기간   재분류  \
# 155414   농협중앙회  인스타그램     1  65880 3 days       4 days  1 days   기저귀
# 153577    롯데카드   오픈마켓     1  53950 2 days       3 days  1 days  위생용품
# 153578   농협중앙회   지인추천     0  53950 2 days       3 days  1 days  위생용품
#
#        구매금액_제품단가 기저귀 단계
# 155414         0    5단계
# 153577     -4050    6단계
# 153578      4050    6단계
#
# [3 rows x 23 columns]

# %%
def quater(x):
    if x <= '2019-03':
        return '2019 1Q'
    elif x <= '2019-06':
        return '2019 2Q'
    elif x <= '2019-09':
        return '2019 3Q'
    elif x <= '2019-12':
        return '2019 4Q'
    elif x <= '2020-03':
        return '2020 1Q'
    elif x <= '2020-06':
        return '2020 2Q'
    else:
        return '2020 3Q'
diper_fin['쿼터별'] = diper_fin['구매일'].apply(quater)
# quater_customer = diper_fin.groupby('쿼터별').agg(count = ('쿼터별', 'count')).reset_index()

# %%
# three = pd.Timedelta(3, "d")
diper_fin['배송기간'].dt.days
# Out:
# 71598     2
# 71599     3
# 71600     3
# 71601     3
# 71602     4
#          ..
# 155031    3
# 155032    2
# 155414    3
# 153577    2
# 153578    2
# Name: 배송기간, Length: 6661, dtype: int64

# %%
diper_fin1 = diper_fin.dropna()

# %%
diper_fin1['기저귀 단계']
# Out:
# 71598     이른둥이
# 71599     이른둥이
# 71600     이른둥이
# 71601     이른둥이
# 71602     이른둥이
#           ...
# 155031     5단계
# 155032     5단계
# 155414     5단계
# 153577     6단계
# 153578     6단계
# Name: 기저귀 단계, Length: 6661, dtype: object

# %% [markdown]
# # 계산 공간

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
from sklearn.datasets import load_breast_cancer

test2 = load_breast_cancer()

X = pd.DataFrame(test2.data, columns=['기저귀 단계']) # input data
y = pd.DataFrame(test2.target, columns=['class']) # target data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [142], in <cell line: 7>()
#       4 import pandas as pd
#       5 from sklearn.datasets import load_breast_cancer
# ----> 7 test2 = load_test2()
#       9 X = pd.DataFrame(test2.data, columns=['기저귀 단계']) # input data
#      10 y = pd.DataFrame(test2.target, columns=['class'])
#
# NameError: name 'load_test2' is not defined

# %%
# scale 변환
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer

scaler = StandardScaler()
scaler.fit(X)

x_scaled = scaler.transform(X)

# %%
test2 = test1.drop('상품명', axis=1)
test3 = test2[['구매시월령(수정)','기저귀 단계']]
test3
# Out:
#        구매시월령(수정)  기저귀 단계
# 0           13.0       1
# 1            5.0       1
# 2           21.0       1
# 3           26.0       1
# 4           26.0       1
# ...          ...     ...
# 42775       22.0       5
# 42776       11.0       5
# 42777        0.0       5
# 42778       18.0       5
# 42779       19.0       5
#
# [42780 rows x 2 columns]

# %%
test3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42780 entries, 0 to 42779
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   구매시월령(수정)  42780 non-null  float64
#  1   기저귀 단계     42780 non-null  int64
# dtypes: float64(1), int64(1)
# memory usage: 668.6 KB

# %%
input = test3['구매시월령(수정)']
target = test3['기저귀 단계']
input, target = mglearn.datasets.make_wave()
plt.scatter(input, target)

# %%
from sklearn import linear_model
import sklearn.model_selection
model = linear_model.LinearRegression()

x = predict_data()

# %%
x = diper_fin.groupby(pd.Grouper(key='구매일', freq='Q'))['구매일'].count().index
y = diper_fin.groupby(pd.Grouper(key='구매일', freq='Q'))[['배송기간']==3].count()
# quarter = pd.date_range('2019-01-01', '2020-09-01', freq='Q').to_series()


plt.figure(figsize=(13,7))
plt.title('기저귀 배송지연 건수', fontdict={'fontsize':20})
for a in purchase_top10:
    x = df2[df2['재분류'] == a].groupby(pd.Grouper(key='구매일', freq='W'))['구매일'].count().index
    y = df2[df2['재분류'] == a].groupby(pd.Grouper(key='구매일', freq='W'))['구매금액'].sum()
    plt.plot(x,y, label=a)
plt.xticks(month, rotation=45)
plt.xlabel('날짜(주)',fontdict={'fontsize':15})
plt.legend()
plt.savefig('재분류 - 날짜별 결제금액.png', dpi=300)
plt.show()

# %%
data_0 = diper_fin[diper_fin['기저귀 단계']=='이른둥이'][['구매시월령(수정)','기저귀 단계']]
data_1 = diper_fin[diper_fin['기저귀 단계']=='1단계'][['구매시월령(수정)','기저귀 단계']]
data_2 = diper_fin[diper_fin['기저귀 단계']=='2단계'][['구매시월령(수정)','기저귀 단계']]
data_3 = diper_fin[diper_fin['기저귀 단계']=='3단계'][['구매시월령(수정)','기저귀 단계']]
data_4 = diper_fin[diper_fin['기저귀 단계']=='4단계'][['구매시월령(수정)','기저귀 단계']]
data_5 = diper_fin[diper_fin['기저귀 단계']=='5단계'][['구매시월령(수정)','기저귀 단계']]
data_6 = diper_fin[diper_fin['기저귀 단계']=='6단계'][['구매시월령(수정)','기저귀 단계']]
data = [data_0, data_1, data_2, data_3, data_4, data_5, data_6]

fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
bp = ax.boxplot(data)
 
# show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [188], in <cell line: 16>()
#      13 ax = fig.add_axes([0, 0, 1, 1])
#      15 # Creating plot
# ---> 16 bp = ax.boxplot(data)
#      18 # show plot
#      19 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3711, in Axes.boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3708 if bootstrap is None:
#    3709     bootstrap = rcParams['boxplot.bootstrap']
# -> 3711 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3712                                labels=labels, autorange=autorange)
#    3713 if notch is None:
#    3714     notch = rcParams['boxplot.notch']
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1155, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1152 bxpstats = []
#    1154 # convert X to a list of lists
# -> 1155 X = _reshape_2D(X, "X")
#    1157 ncols = len(X)
#    1158 if labels is None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1398, in _reshape_2D(X, name)
#    1396     nd = np.ndim(xi)
#    1397     if nd > 1:
# -> 1398         raise ValueError(f'{name} must have 2 or fewer dimensions')
#    1399     result.append(xi.reshape(-1))
#    1401 if is_1d:
#    1402     # 1D array of scalars: directly return it.
#
# ValueError: X must have 2 or fewer dimensions

# %%
plt.scatter(diper_fin['기저귀 단계'], diper_fin['구매시월령(수정)'])
plt.title('기저귀 구매 시 자녀 월령', fontdict={'fontsize':15})
plt.style.use('bmh')
# discount = plt.bar(labels, values, width=0.7)
plt.yticks(fontsize=15)
# plt.grid(True, axis='x')
plt.savefig('재분류 - 총 할인금액.png', dpi=300)



plt.show()

# %%
# sales_data.isnull().sum()

# %%
# product_data[product_data['제품단가'] == 0]

# %%
sales_data['주문번호'].nunique()
# Out:
# 182426

# %%
sac = sales_data[sales_data['주문번호'].str.contains('-')]

# %%
sac['고객번호'].nunique()
# Out:
# 13185

# %%
buy_day = sales_data.sort_values(by = '구매일')

# %%
# member_data.groupby('유입경로').agg(where = ('자녀여부', 'count'))

# %%
# sales_data['구매시월령(수정)'] =  sales_data['구매시월령(수정)'] // 12 +1 -> 나이로 바꾸고 싶을떄

# %%
sales_data['구매시월령(수정)'][0]
# Out:
# 4.0

# %%
# 구매 시 월령 8살 이상
# over_ = sales_data[sales_data['구매시월령(수정)'] >= 8]
# over_

# %%
no_outer = merge_outer[merge_outer['자녀여부'] == 'No']
yes_outer = merge_outer[merge_outer['자녀여부'] == 'Yes']

# %%
product_data['total'].max()
# Out:
# 194683790

# %%
member_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81094 entries, 0 to 81093
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      81094 non-null  float64
#  1   성별      81094 non-null  object
#  2   결혼유무    81094 non-null  object
#  3   거주지역    81094 non-null  object
#  4   연령      81094 non-null  float64
#  5   결제등록카드  81094 non-null  object
#  6   유입경로    81094 non-null  object
#  7   자녀여부    81094 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 5.6+ MB

# %%
member_data
# Out:
#                  ID 성별 결혼유무 거주지역    연령 결제등록카드    유입경로 자녀여부
# 0      2.018123e+14  여   기혼   인천  37.0   국민은행   인스타그램  Yes
# 1      2.018123e+14  여   기혼   제주  33.0   국민은행    검색광고  Yes
# 2      2.018123e+14  여   기혼   부산  32.0   하나은행  네이버블로그  Yes
# 3      2.018123e+14  여   미혼   경남  34.0   기업은행    지인추천   No
# 4      2.018123e+14  여   기혼   서울  32.0   신한은행    직접검색  Yes
# ...             ... ..  ...  ...   ...    ...     ...  ...
# 81089  2.019123e+14  여   기혼   경기  31.0   국민은행    오픈마켓  Yes
# 81090  2.019123e+14  여   기혼   경남  37.0   롯데카드    오픈마켓  Yes
# 81091  2.019123e+14  여   기혼   충북  26.0   삼성카드    검색광고  Yes
# 81092  2.019123e+14  여   기혼   경기  32.0  새마을금고   인스타그램  Yes
# 81093  2.019123e+14  여   기혼   서울  35.0  새마을금고   인스타그램  Yes
#
# [81094 rows x 8 columns]

# %%
product_data[product_data['물품대분류'] == 'FMC']
# Out:
#     물품대분류                                                상품명  물품판매량   제품단가
# 255   FMC  (1+1) 크리넥스 버블버블 핸드워시 그린향 거품펌프형 250ml + 용기형리필 2...     30      0
# 256   FMC  (1+1) 크리넥스 버블버블 핸드워시 상큼향 거품펌프형 250ml + 용기형리필 2...     17      0
# 257   FMC                            (핫딜위크/1+1) 스카트 주방 위생 세트     12      0
# 258   FMC               (핫딜위크/1+1) 크리넥스 칼로리라이트 키친타월 55매 X 3롤      6      0
# 259   FMC              [1+1] 스카트 항균 프레쉬블루 빨아쓰는 행주타월 45매 X 4롤     30  24800
# ..    ...                                                ...    ...    ...
# 475   FMC                           크리넥스 황사마스크 뉴디자인플러스 대형 3P    209  11866
# 476   FMC                           크리넥스 황사마스크 뉴디자인플러스 소형 3P    309  16037
# 477   FMC                             크리넥스 황사용 마스크 플러스 대형10P    222  19871
# 478   FMC                                        크리넥스/스카트 세트     54  38100
# 479   FMC                             크리넥스？키즈용？화장지？3겹？27m 8롤    450   8864
#
# [225 rows x 4 columns]

# %%
sales_data['구매시월령(수정)'].describe()
# Out:
# count    168142.000000
# mean         14.845458
# std          38.521315
# min         -10.000000
# 25%           2.000000
# 50%           6.000000
# 75%          13.000000
# max        1439.000000
# Name: 구매시월령(수정), dtype: float64

# %%
sales_data['구매시월령(수정)'].describe()
# Out:
# count    168142.000000
# mean         14.845458
# std          38.521315
# min         -10.000000
# 25%           2.000000
# 50%           6.000000
# 75%          13.000000
# max        1439.000000
# Name: 구매시월령(수정), dtype: float64

# %%
test1 = pd.read_csv('diaper.csv')

# %%
test1.to_excel('diaper.xlsx')
